# %%
# !pip install pyspark
import pandas as pd
from platform import python_version
from pyspark.context import SparkContext
sc = SparkContext.getOrCreate()
from operator import add
from pyspark.sql import SparkSession
app_names = "ReadJSON, ReadCSV"
spark = SparkSession.builder.appName(app_names).getOrCreate()
import matplotlib.pyplot as plt
from wordcloud import WordCloud  # Import WordCloud class
from pyspark.sql.functions import explode, col, lit
from pyspark.sql.functions import when
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %% [markdown]
# # Lyrics Data

# %%
rdd = sc.textFile("/content/lyrics.jl")

rdd.take(10)
# Out:
# ['{"song": "Kendrick-lamar-swimming-pools-drank-lyrics", "lyrics": "\\n\\n[Produced by T-Minus]\\n\\n[Intro]\\nPour up (Drank), head shot (Drank)\\nSit down (Drank), stand up (Drank)\\nPass out (Drank), wake up (Drank)\\nFaded (Drank), faded (Drank)\\n\\n[Verse 1]\\nNow I done grew up \'round some people livin\' their life in bottles\\nGranddaddy had the golden flask\\nBackstroke every day in Chicago\\nSome people like the way it feels\\nSome people wanna kill their sorrows\\nSome people wanna fit in with the popular, that was my problem\\nI was in a dark room, loud tunes\\nLookin\' to make a vow soon\\nThat I\'ma get fucked up, fillin\' up my cup I see the crowd mood\\nChangin\' by the minute and the record on repeat\\nTook a sip, then another sip, then somebody said to me\\n\\n[Chorus]\\nNigga, why you babysittin\' only two or three shots?\\nI\'ma show you how to turn it up a notch\\nFirst you get a swimming pool full of liquor, then you dive in it\\nPool full of liquor, then you dive in it\\nI wave a few bottles, then I watch \'em all flock\\nAll the girls wanna play Baywatch\\nI got a swimming pool full of liquor and they dive in it\\nPool full of liquor, I\'ma dive in it\\n\\n[Refrain]\\nPour up (Drank), head shot (Drank)\\nSit down (Drank), stand up (Drank)\\nPass out (Drank), wake up (Drank)\\nFaded (Drank), faded (Drank)\\n\\n[Verse 2]\\nOkay, now open your mind up and listen me, Kendrick\\nI am your conscience, if you do not hear me\\nThen you will be history, Kendrick\\nI know that you\'re nauseous right now\\nAnd I\'m hopin\' to lead you to victory, Kendrick\\nIf I take another one down\\nI\'ma drown in some poison, abusin\' my limit\\nI think that I\'m feelin\' the vibe, I see the love in her eyes\\nI see the feelin\', the freedom is granted\\nAs soon as the damage of vodka arrived\\nThis how you capitalize, this is parental advice\\nThen apparently, I\'m over-influenced by what you are doin\'\\nI thought I was doin\' the most \'til someone said to me\\n\\n[Chorus]\\nNigga, why you babysittin\' only two or three shots?\\nI\'ma show you how to turn it up a notch\\nFirst you get a swimming pool full of liquor, then you dive in it\\nPool full of liquor, then you dive in it\\nI wave a few bottles, then I watch \'em all flock\\nAll the girls wanna play Baywatch\\nI got a swimming pool full of liquor and they dive in it\\nPool full of liquor, I\'ma dive in it\\n\\n[Refrain]\\nPour up (Drank), head shot (Drank)\\nSit down (Drank), stand up (Drank)\\nPass out (Drank), wake up (Drank)\\nFaded (Drank), faded (Drank)\\n\\n[Bridge]\\nI ride, you ride, bang\\nOne chopper, 100
# Step 2: Split lyrics into words and create a new dictionary
def split_vocabulary(dictionary):
    lyrics = dictionary.get('lyrics', '')  # Get the 'lyrics' field from the dictionary
    # Remove all characters that are not words, numbers, underscores, or spaces
    cleaned_lyrics = re.sub(r'[^\w\s]', '', lyrics)

    # Split the cleaned lyrics into words
    words = re.split(r'[;,*\n\s()\[\]\'":—-]+|(?<=--)|(?=--)', cleaned_lyrics)
    words = [word.lower() for word in words if word.strip()]


    return {'song': dictionary.get('song', ''), 'vocabulary': words}

# Step 3: Apply the split_vocabulary function to each dictionary
rdd_with_vocabulary = rdd2.map(split_vocabulary)

# Step 4: Take the first 10 records from the transformed RDD
first_10_records = rdd_with_vocabulary.take(10)

# Display the first 10 records
for record in first_10_records:
    print(record)
# Out:
# {'song': 'Kendrick-lamar-swimming-pools-drank-lyrics', 'vocabulary': ['produced', 'by', 'tminus', 'intro', 'pour', 'up', 'drank', 'head', 'shot', 'drank', 'sit', 'down', 'drank', 'stand', 'up', 'drank', 'pass', 'out', 'drank', 'wake', 'up', 'drank', 'faded', 'drank', 'faded', 'drank', 'verse', '1', 'now', 'i', 'done', 'grew', 'up', 'round', 'some', 'people', 'livin', 'their', 'life', 'in', 'bottles', 'granddaddy', 'had', 'the', 'golden', 'flask', 'backstroke', 'every', 'day', 'in', 'chicago', 'some', 'people', 'like', 'the', 'way', 'it', 'feels', 'some', 'people', 'wanna', 'kill', 'their', 'sorrows', 'some', 'people', 'wanna', 'fit', 'in', 'with', 'the', 'popular', 'that', 'was', 'my', 'problem', 'i', 'was', 'in', 'a', 'dark', 'room', 'loud', 'tunes', 'lookin', 'to', 'make', 'a', 'vow', 'soon', 'that', 'ima', 'get', 'fucked', 'up', 'fillin', 'up', 'my', 'cup', 'i', 'see', 'the', 'crowd', 'mood', 'changin', 'by', 'the', 'minute', 'and', 'the', 'record', 'on', 'repeat', 'took', 'a', 'sip', 'then', 'another', 'sip', 'then', 'somebody', 'said', 'to', 'me', 'chorus', 'nigga', 'why', 'you', 'babysittin', 'only', 'two', 'or', 'three', 'shots', 'ima', 'show', 'you', 'how', 'to', 'turn', 'it', 'up', 'a', 'notch', 'first', 'you', 'get', 'a', 'swimming', 'pool', 'full', 'of', 'liquor', 'then', 'you', 'dive', 'in', 'it', 'pool', 'full', 'of', 'liquor', 'then', 'you', 'dive', 'in', 'it', 'i', 'wave', 'a', 'few', 'bottles', 'then', 'i', 'watch', 'em', 'all', 'flock', 'all', 'the', 'girls', 'wanna', 'play', 'baywatch', 'i', 'got', 'a', 'swimming', 'pool', 'full', 'of', 'liquor', 'and', 'they', 'dive', 'in', 'it', 'pool', 'full', 'of', 'liquor', 'ima', 'dive', 'in', 'it', 'refrain', 'pour', 'up', 'drank', 'head', 'shot', 'drank', 'sit', 'down', 'drank', 'stand', 'up', 'drank', 'pass', 'out', 'drank', 'wake', 'up', 'drank', 'faded', 'drank', 'faded', 'drank', 'verse', '2', 'okay', 'now', 'open', 'your', 'mind', 'up', 'and', 'listen', 'me', 'kendrick', 'i', 'am', 'your', 'conscience', 'if', 'you', 'do
 'have', 'a', 'fuckin', 'readalong', 'aint', 'a', 'fuckin', 'singalong', 'less', 'you', 'brought', 'the', 'weed', 'along', 'then', 'ju', 'okay', 'i', 'got', 'it', 'then', 'just', 'drop', 'down', 'and', 'get', 'your', 'eagle', 'on', 'or', 'we', 'can', 'stare', 'up', 'at', 'the', 'stars', 'and', 'put', 'the', 'beatles', 'on', 'all', 'that', 'shit', 'you', 'talkin', 'bout', 'is', 'not', 'up', 'for', 'discussion', 'i', 'will', 'pay', 'to', 'make', 'it', 'bigger', 'i', 'dont', 'pay', 'for', 'no', 'reduction', 'if', 'its', 'comin', 'from', 'a', 'nigga', 'i', 'dont', 'know', 'then', 'i', 'dont', 'trust', 'it', 'if', 'you', 'comin', 'for', 'my', 'head', 'then', 'motherfucker', 'get', 'to', 'bustin', 'yes', 'lord', 'i', 'dont', 'really', 'say', 'this', 'often', 'but', 'this', 'longdick', 'nigga', 'aint', 'for', 'the', 'long', 'talkin', 'im', 'beast', 'chorus', '2', 'chainz', 'drake', 'both', ' ...
# {'song': 'Kendrick-lamar-dna-lyrics', 'vocabulary': ['verse', '1', 'i', 'got', 'i', 'got', 'i', 'got', 'i', 'got', 'loyalty', 'got', 'royalty', 'inside', 'my', 'dna', 'cocaine', 'quarter', 'piece', 'got', 'war', 'and', 'peace', 'inside', 'my', 'dna', 'i', 'got', 'power', 'poison', 'pain', 'and', 'joy', 'inside', 'my', 'dna', 'i', 'got', 'hustle', 'though', 'ambition', 'flow', 'inside', 'my', 'dna', 'i', 'was', 'born', 'like', 'this', 'since', 'one', 'like', 'this', 'immaculate', 'conception', 'i', 'transform', 'like', 'this', 'perform', 'like', 'this', 'was', 'yeshua', 'new', 'weapon', 'i', 'dont', 'contemplate', 'i', 'meditate', 'then', 'off', 'your', 'fucking', 'head', 'this', 'that', 'putthekidstobed', 'this', 'that', 'i', 'got', 'i', 'got', 'i', 'got', 'i', 'got', 'realness', 'i', 'just', 'kill', 'shit', 'cause', 'its', 'in', 'my', 'dna', 'i', 'got', 'millions', 'i', 'got', 'riches', 'buildin', 'in', 'my', 'dna', 'i', 'got', 'dark', 'i', 'got', 'evil', 'that', 'rot', 'inside', 'my', 'dna', 'i', 'got', 'off', 'i', 'got', 'troublesome', 'heart', 'inside', 'my', 'dna', 'i', 'just', 'win', 'again', 'then', 'win', 'again', 'like', 'wimbledon', 'i', 'serve', 'yeah', 'thats', 'him', 'again', 'the', 'sound', 'that', 'engine', 'in', 'is', 'like', 'a', 'bird', 'you', 'see', 'fireworks', 'and', 'corvette', 'tire', 'skrrt', 'the', 'boulevard', 'i', 'know', 'how', 'you', 'work', 'i', 'know', 'just', 'who', 'you', 'are', 'see', 'yous', 'a', 'yous', 'a', 'yous', 'a', 'bitch', 'your', 'hormones', 'prolly', 'switch', 'inside', 'your', 'dna', 'problem', 'is', 'all', 'that', 'sucker', 'shit', 'inside', 'your', 'dna', 'daddy', 'prolly', 'snitched', 'heritage', 'inside', 'your', 'dna', 'backbone', 'dont', 'exist', 'born', 'outside', 'a', 'jellyfish', 
', 'now', 'big', 'gold', 'chains', 'full', 'of', 'rocks', 'how', 'you', 'no', 'see', 'the', 'whip', 'left', 'scars', 'pon', 'me', 'back', 'but', 'now', 'we', 'have', 'a', 'big', 'whip', 'parked', 'pon', 'the', 'block', 'all', 'them', 'say', 'we', 'doomed', 'from', 'the', 'start', 'cah', 'we', 'black', 'remember', 'this', 'every', 'race', 'start', 'from', 'the', 'block', 'jus', 'member', 'dat', 'verse', '2', 'kendrick', 'lamar', 'im', 'the', 'biggest', 'hypocrite', 'of', '2015', 'once', 'i', 'finish', 'this', 'witnesses', 'will', 'convey', 'just', 'what', 'i', 'mean', 'i', 'mean', 'its', 'evident', 'that', 'im', 'irrelevant', 'to', 'society', 'thats', 'what', 'youre', 'telling', 'me', 'penitentiary', 'would', 'only', 'hire', 'me', 'curse', 'me', 'till', 'im', 'dead', 'church', 'me', 'with', 'your', 'fake', 'prophesizing', 'that', 'ima', 'be', 'just', 'another', 'slave', 'in', ' ...

# %%
def count_words_in_dictionary(dictionary):
    vocabulary = dictionary.get('vocabulary', [])  # Get the 'vocabulary' list or an empty list if not present
    word_counts = {}

    for word in vocabulary:
        word_counts[word] = word_counts.get(word, 0) + 1  # Count word occurrences

    return {'song': dictionary.get('song', ''), 'word_counts': word_counts}

# Apply the function to your RDD containing dictionaries with 'vocabulary'
rdd_with_word_counts = rdd_with_vocabulary.map(count_words_in_dictionary)

# Take the first 10 records from the transformed RDD
rdd_with_word_counts.take(10)
# Out:
# [{'song': 'Kendrick-lamar-swimming-pools-drank-lyrics',
#   'word_counts': {'produced': 1,
#    'by': 3,
#    'tminus': 1,
#    'intro': 1,
#    'pour': 4,
#    'up': 25,
#    'drank': 32,
#    'head': 4,
#    'shot': 4,
#    'sit': 4,
#    'down': 5,
#    'stand': 4,
#    'pass': 4,
#    'out': 8,
#    'wake': 7,
#    'faded': 8,
#    'verse': 3,
#    '1': 1,
#    'now': 4,
#    'i': 32,
#    'done': 1,
#    'grew': 1,
#    'round': 1,
#    'some': 5,
#    'people': 4,
#    'livin': 1,
#    'their': 2,
#    'life': 2,
#    'in': 22,
#    'bottles': 4,
#    'granddaddy': 1,
#    'had': 2,
#    'the': 21,
#    'golden': 1,
#    'flask': 1,
#    'backstroke': 1,
#    'every': 1,
#    'day': 1,
#    'chicago': 1,
#    'like': 2,
#    'way': 1,
#    'it': 17,
#    'feels': 1,
#    'wanna': 5,
#    'kill': 1,
#    'sorrows': 1,
#    'fit': 1,
#    'with': 1,
#    'popular': 1,
#    'that': 14,
#    'was': 3,
#    'my': 5,
#    'problem': 1,
#    'a': 17,
#    'dark': 1,
#    'room': 1,
#    'loud': 1,
#    'tunes': 1,
#    'lookin': 1,
#    'to': 8,
#    'make': 1,
#    'vow': 1,
#    'soon': 2,
#    'ima': 9,
#    'get': 4,
#    'fucked': 1,
#    'fillin': 1,
#    'cup': 1,
#    'see': 5,
#    'crowd': 1,
#    'mood': 1,
#    'changin': 1,
#    'minute': 1,
#    'and': 12,
#    'record': 1,
#    'on': 1,
#    'repeat': 1,
#    'took': 1,
#    'sip': 2,
#    'then': 14,
#    'another': 2,
#    'somebody': 2,
#    'said': 2,
#    'me': 9,
#    'chorus': 3,
#    'nigga': 4,
#    'why': 4,
#    'you': 32,
#    'babysittin': 3,
#    'only': 3,
#    'two': 5,
#    'or': 3,
#    'three': 3,
#    'shots': 8,
#    'show': 3,
#    'how': 4,
#    'turn': 3,
#    'notch': 3,
#    'first': 3,
#    'swimming': 6,
#    'pool': 12,
#    'full': 12,
#    'of': 15,
#    'liquor': 12,
#    'dive': 12,
#    'wave': 3,
#    'few': 4,
#    'watch': 3,
#    'em': 3,
#    'all': 7,
#    'flock': 3,
#    'girls': 3,
#    'play': 3,
#    'baywatch': 3,
#    'got': 5,
#    'they': 7,
#    'refrain': 3,
#    '2': 1,
#    'okay': 1,
#    'open': 2,
#    'your': 3,
#    'mind': 1,
#    'listen': 1,
#    'kendrick': 3,
#    'am': 1,
#    'conscience': 1,
#    'if': 3,
#    'do': 6,
#    'not': 1,
#    'hear': 1,
#    'will': 1,
#    'be': 1,
#    'history': 1,
#    'know': 1,
#    'youre': 2,
#    'nauseous': 1,
#    'right': 2,
#    'im': 4,
#    'hopin': 1,
#    'lead': 1,
#    'victory': 1,
#    'take': 1,
#    'one': 3,
#    'drown': 1,
#    'poison': 1,
#    'abusin': 1,
#    'limit': 1,
#    'think': 1,
#    'feelin': 2,
#    'vibe': 1,
#    'love': 1,
#    'her': 1,
#    'eyes': 1,
#    'freedom': 1,
#    'is': 6,
#    'granted': 1,
#    'as': 4,
#    'damage': 1,
#    'vodka': 1,
#    'arrived': 1,
#    'this': 2,
#    'capitalize': 1,
#    'parental': 1,
#    'advice': 1,
#    'apparently': 1,
#    'overinfluenced': 1,
#    'what': 1,
#    'are': 2,
#    'doin': 2,
#    'thought': 2,
#    'most': 1,
#    'til': 1,
#    'someone': 1,
#    'bridge': 1,
#    'ride': 4,
#    'bang': 8,
#    'chopper': 4,
#    '100': 2,
#    'hop': 2,
#    '200': 2,
#    'interlude': 1,
#    'sherane': 1,
#    'aw': 1,
#    'man': 2,
#    'where': 2,
#    'she': 2,
#    'takin': 2,
#    '3': 1,
#    'have': 1,
#    'new': 1,
#    'appetite': 1,
#    'for': 1,
#    'failure': 1,
#    'hunger': 1,
#    'pain': 1,
#    'grow': 1,
#    'insane': 1,
#    'tell': 1,
#    'sound': 1,
#    'familiar': 1,
#    'makin': 1,
#    'excuse': 1,
#    'relief': 1,
#    'bottom': 1,
#    'bottle': 1,
#    'greenest': 1,
#    'indo': 1,
#    'leaf': 1,
#    'window': 1,
#    'release': 1,
#    'everything': 1,
#    'corrode': 1,
#    'inside': 1,
#    'jokin': 1,
#    'laugh': 1,
#    'dont': 1,
#    'feel': 1,
#    'bad': 1,
#    'probably': 1,
#    'sleep': 1,
#    'never': 3,
#    'ever': 3,
#    'god': 1,
#    'trust': 1,
#    'but': 1,
#    'just': 1,
#    'when': 1,
#    'enough': 1,
#    'outro': 1,
#    'stomped': 1,
#    'homie': 1,
#    'over': 1,
#    'bitch': 3,
#    'kdot': 2,
#    'good': 5,
#    'blood': 2,
#    'we': 4,
#    'can': 2,
#    'drop': 2,
#    'ye': 1,
#    'back': 1,
#    'off': 1,
#    'niggas': 3,
#    'straight': 1,
#    'aint': 1,
#    'trippin': 1,
#    'gon': 5,
#    'same': 1,
#    'ol': 1,
#    'shit': 1,
#    'pop': 2,
#    'run': 2,
#    'opposite': 1,
#    'ways': 1,
#    'fall': 1,
#    's': 1,
#    'lap': 1,
#    'he': 1,
#    'tear': 1,
#    'ass': 1,
#    'simple': 1,
#    'hope': 1,
#    'set': 1,
#    'him': 1,
#    'there': 1,
#    'too': 1,
#    'wait': 1,
#    'hold': 1,
#    'ayy': 1,
#    'car': 1,
#    'door': 1,
#    'opens': 1,
#    'gunshots': 1,
#    'fired': 1,
#    'aha': 1,
#    'them': 1,
#    'l': 1,
#    'yeah': 1,
#    'dave': 4,
#    'say': 1,
#    'somethin': 1,
#    'these': 1,
#    'bitchass': 1,
#    'killed': 1,
#    'brother': 1}},
#  {'song': 'Kendrick-lamar-money-trees-lyrics',
#   'word_counts': {'produced': 1,
#    'by': 1,
#    'dj': 1,
#    'dahi': 1,
#    'verse': 4,
#    '1': 1,
#    'kendrick': 6,
#    'lamar': 5,
#    'uh': 1,
#    'me': 6,
#    'and': 19,
#    'my': 16,
#    'niggas': 5,
#    'tryna': 2,
#    'get': 6,
#    'it': 9,
#    'ya': 24,
#    'bish': 26,
#    'hit': 5,
#    'the': 44,
#    'house': 2,
#    'lick': 1,
#    'tell': 9,
#    'is': 11,
#    'you': 17,
#    'wit': 1,
#    'home': 2,
#    'invasion': 1,
#    'was': 2,
#    'persuasive': 2,
#    'from': 4,
#    'nine': 1,
#    'to': 14,
#    'five': 1,
#    'i': 26,
#    'know': 3,
#    'its': 2,
#    'vacant': 1,
#    'dreams': 3,
#    'of': 16,
#    'livin': 2,
#    'life': 2,
#    'like': 6,
#    'rappers': 4,
#    'do': 6,
#    'back': 6,
#    'when': 7,
#    'condom': 1,
#    'wrappers': 1,
#    'wasnt': 2,
#    'cool': 2,
#    'they': 5,
#    'fucked': 1,
#    'sherane': 1,
#    'went': 1,
#    'bros': 2,
#    'then': 5,
#    'usher': 1,
#    'raymond': 1,
#    'let': 2,
#    'burn': 2,
#    'came': 4,
#    'on': 8,
#    'hot': 1,
#    'sauce': 1,
#    'all': 8,
#    'in': 12,
#    'our': 3,
#    'top': 1,
#    'ramen': 1,
#    'park': 1,
#    'car': 4,
#    'we': 11,
#    'start': 1,
#    'rhymin': 1,
#    'only': 1,
#    'thing': 2,
#    'had': 2,
#    'free': 2,
#    'mind': 2,
#    'freeze': 1,
#    'that': 16,
#    'see': 5,
#    'dollar': 10,
#    'signs': 3,
#    'lookin': 1,
#    'a': 24,
#    'easy': 1,
#    'comeup': 1,
#    'silver': 1,
#    'spoon': 1,
#    'come': 1,
#    'thats': 12,
#    'lifestyle': 1,
#    'never': 4,
#    'knew': 2,
#    'go': 4,
#    'at': 3,
#    'reverend': 1,
#    'for': 6,
#    'revenue': 1,
#    'hook': 3,
#    'halle': 3,
#    'berry': 3,
#    'or': 3,
#    'hallelujah': 3,
#    'pick': 4,
#    'your': 13,
#    'poison': 3,
#    'what': 5,
#    'doin': 3,
#    'everybody': 3,
#    'gon': 4,
#    'respect': 3,
#    'shooter': 3,
#    'but': 5,
#    'one': 12,
#    'front': 6,
#    'gun': 6,
#    'lives': 3,
#    'forever': 6,
#    'been': 3,
#    'hustlin': 4,
#    'day': 7,
#    'thisaway': 3,
#    'thataway': 3,
#    'through': 3,
#    'canals': 3,
#    'alleyways': 3,
#    'just': 25,
#    'say': 7,
#    'money': 4,
#    'trees': 3,
#    'perfect': 3,
#    'place': 3,
#    'shade': 3,
#    'how': 11,
#    'feel': 11,
#    'nah': 12,
#    'might': 9,
#    'fuck': 5,
#    'main': 2,
#    'bitch': 2,
#    'them': 9,
#    'with': 6,
#    'make': 2,
#    'lane': 2,
#    'switch': 2,
#    'turn': 2,
#    'million': 2,
#    'rich': 2,
#    '2': 1,
#    'bump': 1,
#    'new': 1,
#    'e40': 1,
#    'after': 2,
#    'school': 2,
#    'way': 10,
#    'big': 3,
#    'ballin': 1,
#    'homies': 2,
#    'earl': 1,
#    'stevens': 1,
#    'us': 1,
#    'thinkin': 2,
#    'rational': 2,
#    'reality': 1,
#    'poor': 1,
#    'another': 2,
#    'casualty': 1,
#    'war': 1,
#    'two': 1,
#    'bullets': 1,
#    'uncle': 1,
#    'tony': 2,
#    'head': 2,
#    'he': 6,
#    'said': 1,
#    'ill': 1,
#    'be': 6,
#    'tour': 1,
#    'louis': 2,
#    'burgers': 1,
#    'same': 2,
#    'wont': 2,
#    'belt': 1,
#    'will': 1,
#    'ease': 2,
#    'pain': 2,
#    'ima': 1,
#    'purchase': 1,
#    'jerkin': 2,
#    'pull': 1,
#    'off': 2,
#    'churchs': 1,
#    'pirellis': 2,
#    'skirtin': 2,
#    'gang': 1,
#    'out': 5,
#    'window': 1,
#    'hopin': 1,
#    'em': 1,
#    'offend': 1,
#    'hood': 1,
#    'pot': 2,
#    'gold': 2,
#    'crash': 1,
#    'nobodys': 1,
#    'bridge': 1,
#    'anna': 1,
#    'wise': 1,
#    'last': 3,
#    'this': 4,
#    'dough': 2,
#    'no': 9,
#    'love': 2,
#    'bucketheaded': 2,
#    'hoes': 2,
#    'streets': 3,
#    'break': 2,
#    'code': 2,
#    'brakes': 2,
#    'patrol': 2,
#    '3': 1,
#    'jay': 1,
#    'rock': 2,
#    'imagine': 1,
#    'up': 3,
#    'projects': 1,
#    'where': 3,
#    'pockets': 1,
#    'santa': 1,
#    'claus': 1,
#    'dont': 2,
#    'miss': 1,
#    'stockings': 1,
#    'liquors': 1,
#    'spillin': 1,
#    'pistols': 1,
#    'poppin': 1,
#    'bakin': 1,
#    'soda': 1,
#    'yola': 1,
#    'whippin': 1,
#    'aint': 3,
#    'turkey': 1,
#    'thanksgivin': 1,
#    'homeboy': 1,
#    'domed': 1,
#    'nigga': 1,
#    'hope': 2,
#    'lord': 1,
#    'forgive': 1,
#    'him': 2,
#    'pots': 1,
#    'cocaine': 1,
#    'residue': 1,
#    'every': 1,
#    'im': 2,
#    'else': 1,
#    'thug': 1,
#    'eatin': 1,
#    'cheese': 1,
#    'government': 1,
#    'gotta': 1,
#    'provide': 1,
#    'daughter': 1,
#    'nem': 1,
#    'got': 2,
#    'drum': 1,
#    'bands': 1,
#    'parade': 1,
#    'drop': 1,
#    'work': 1,
#    'bushes': 1,
#    'boys': 1,
#    'stash': 1,
#    'if': 1,
#    'truth': 1,
#    'time': 3,
#    'ass': 3,
#    'gardens': 1,
#    'grass': 1,
#    'cut': 1,
#    'serpents': 1,
#    'lurkin': 1,
#    'blood': 1,
#    'bitches': 1,
#    'sellin': 2,
#    'pussy': 1,
#    'drugs': 1,
#    'good': 3,
#    'broken': 1,
#    'promises': 1,
#    'steal': 1,
#    'watch': 1,
#    'take': 1,
#    'js': 1,
#    'kick': 1,
#    'footlocker': 1,
#    'heater': 1,
#    'under': 2,
#    'dungarees': 1,
#    'gettin': 1,
#    'shaded': 1,
#    'tree': 1,
#    'outro': 1,
#    'ks': 4,
#    'mom': 2,
#    'bring': 3,
#    'man': 3,
#    'called': 1,
#    'appointment': 1,
#    'figured': 1,
#    'werent': 1,
#    'gonna': 1,
#    'here': 1,
#    'anyways': 1,
#    'look': 2,
#    'shit': 5,
#    'wanna': 1,
#    'feelin': 2,
#    'as': 2,
#    'motherfucker': 1,
#    'goin': 1,
#    'too': 1,
#    'faded': 1,
#    'listen': 1,
#    'dad': 2,
#    'girl': 4,
#    'want': 4,
#    'body': 4,
#    'cause': 2,
#    'ol': 2,
#    'fat': 2,
#    'high': 1,
#    'hell': 1,
#    'even': 1,
#    'trippin': 1,
#    'damn': 1,
#    'dominoes': 2,
#    'anymore': 1,
#    'did': 1,
#    'somebody': 1}},
#  {'song': 'Kendrick-lamar-xxx-lyrics',
#   'word_counts': {'intro': 1,
#    'bēkon': 1,
#    'kid': 1,
#    'capri': 1,
#    'america': 4,
#    'god': 2,
#    'bless': 2,
#    'you': 20,
#    'if': 3,
#    'its': 5,
#    'good': 1,
#    'to': 15,
#    'please': 1,
#    'take': 3,
#    'my': 12,
#    'hand': 1,
#    'can': 2,
#    'help': 1,
#    'me': 9,
#    'underst': 1,
#    'new': 1,
#    'kung': 1,
#    'fu': 1,
#    'kenny': 1,
#    'verse': 3,
#    '1': 1,
#    'kendrick': 4,
#    'lamar': 4,
#    'throw': 4,
#    'a': 21,
#    'steak': 1,
#    'off': 1,
#    'the': 21,
#    'ark': 1,
#    'pool': 1,
#    'full': 1,
#    'of': 11,
#    'sharks': 1,
#    'hell': 3,
#    'it': 6,
#    'leave': 1,
#    'him': 8,
#    'in': 11,
#    'wilderness': 1,
#    'with': 5,
#    'sworn': 1,
#    'nemesis': 1,
#    'make': 1,
#    'gratitude': 1,
#    'from': 2,
#    'i': 12,
#    'bet': 2,
#    'show': 2,
#    'somethin': 1,
#    'whoa': 1,
#    'ill': 8,
#    'chip': 6,
#    'nigga': 7,
#    'lil': 3,
#    'bit': 3,
#    'nothin': 3,
#    'then': 7,
#    'blower': 3,
#    'his': 7,
#    'lap': 3,
#    'walk': 2,
#    'myself': 2,
#    'court': 2,
#    'like': 5,
#    'bitch': 2,
#    'did': 2,
#    'that': 4,
#    'xrated': 1,
#    'johnny': 4,
#    'dont': 2,
#    'wanna': 2,
#    'go': 1,
#    'school': 1,
#    'no': 5,
#    'mo': 4,
#    'said': 3,
#    'books': 1,
#    'aint': 2,
#    'cool': 1,
#    'be': 5,
#    'rapper': 1,
#    'big': 2,
#    'cousin': 1,
#    'caught': 1,
#    'body': 1,
#    'yesterday': 2,
#    'out': 2,
#    'hustlin': 1,
#    'know': 3,
#    'we': 3,
#    'all': 3,
#    'love': 2,
#    '2': 1,
#    'got': 2,
#    'call': 2,
#    'dog': 1,
#    '101': 1,
#    'they': 1,
#    'killed': 3,
#    'only': 1,
#    'son': 2,
#    'because': 1,
#    'insufficient': 1,
#    'funds': 1,
#    'he': 4,
#    'was': 3,
#    'sobbin': 1,
#    'mobbin': 1,
#    'way': 1,
#    'belligerent': 1,
#    'and': 10,
#    'drunk': 1,
#    'talkin': 1,
#    'head': 1,
#    'philosophin': 1,
#    'on': 4,
#    'what': 4,
#    'lord': 1,
#    'had': 1,
#    'done': 1,
#    'kdot': 1,
#    'pray': 2,
#    'for': 6,
#    'been': 1,
#    'fucked': 1,
#    'up': 3,
#    'day': 1,
#    'anointed': 1,
#    'how': 2,
#    'overcome': 1,
#    'lookin': 1,
#    'some': 1,
#    'closure': 1,
#    'hopin': 1,
#    'could': 2,
#    'bring': 1,
#    'closer': 1,
#    'spiritual': 1,
#    'spirit': 1,
#    'do': 3,
#    'better': 1,
#    'but': 2,
#    'told': 1,
#    'cant': 2,
#    'sugarcoat': 1,
#    'answer': 1,
#    'this': 4,
#    'is': 5,
#    'feel': 1,
#    'somebody': 3,
#    'kill': 1,
#    'mean': 1,
#    'gettin': 1,
#    'tell': 2,
#    'loyalty': 1,
#    'passion': 1,
#    'memories': 1,
#    'collected': 1,
#    'moments': 1,
#    'never': 2,
#    'touch': 8,
#    'wait': 1,
#    'front': 1,
#    'niggas': 1,
#    'spot': 1,
#    'watch': 1,
#    'hit': 1,
#    'block': 1,
#    'catch': 1,
#    'leavin': 1,
#    'service': 1,
#    'thats': 2,
#    'black': 1,
#    'power': 1,
#    'when': 2,
#    'your': 4,
#    'baby': 1,
#    'by': 1,
#    'coward': 1,
#    'even': 1,
#    'keep': 1,
#    'peace': 1,
#    'fuck': 1,
#    'one': 1,
#    'ours': 1,
#    'murder': 2,
#    'street': 5,
#    'bodies': 1,
#    'hour': 1,
#    'ghetto': 1,
#    'bird': 1,
#    'paramedics': 1,
#    'dial': 1,
#    'let': 1,
#    'momma': 1,
#    'sister': 1,
#    'woman': 1,
#    'daddy': 1,
#    'niece': 1,
#    'nephew': 1,
#    'brother': 1,
#    'should': 1,
#    'matter': 1,
#    'fact': 1,
#    'im': 1,
#    'bout': 1,
#    'speak': 1,
#    'at': 1,
#    'convention': 1,
#    'back': 2,
#    'break': 1,
#    'alright': 1,
#    'kids': 1,
#    'were': 1,
#    'gonna': 1,
#    'talk': 1,
#    'about': 1,
#    'gun': 1,
#    'control': 1,
#    'damn': 1,
#    'chorus': 2,
#    'bono': 2,
#    'not': 2,
#    'place': 2,
#    'country': 2,
#    'sound': 2,
#    'drum': 2,
#    'bass': 2,
#    'close': 2,
#    'eyes': 2,
#    'look': 3,
#    'around': 1,
#    '3': 1,
#    'hail': 1,
#    'mary': 1,
#    'jesus': 1,
#    'joseph': 1,
#    'great': 1,
#    'american': 2,
#    'flag': 1,
#    'wrapped': 1,
#    'drag': 1,
#    'explosives': 1,
#    'compulsive': 1,
#    'disorder': 1,
#    'sons': 1,
#    'daughters': 1,
#    'barricaded': 1,
#    'blocks': 1,
#    'borders': 1,
#    'taught': 1,
#    'us': 4,
#    'streets': 1,
#    'wall': 1,
#    'corporate': 1,
#    'offices': 1,
#    'banks': 1,
#    'employees': 1,
#    'bosses': 1,
#    'homicidal': 1,
#    'thoughts': 1,
#    'donald': 1,
#    'trumps': 1,
#    'office': 1,
#    'lost': 1,
#    'barack': 1,
#    'promised': 1,
#    'doubt': 1,
#    'again': 1,
#    'honest': 1,
#    'or': 3,
#    'bask': 1,
#    'sin': 1,
#    'pass': 1,
#    'gin': 1,
#    'mix': 1,
#    'blood': 2,
#    'bash': 1,
#    'crippin': 1,
#    'married': 1,
#    'ask': 1,
#    'againoops': 1,
#    'accident': 1,
#    'nasty': 1,
#    'set': 1,
#    'roll': 1,
#    'dice': 1,
#    'overnight': 1,
#    'rifles': 1,
#    'fox': 1,
#    'scared': 1,
#    'gang': 1,
#    'members': 1,
#    'terrorists': 1,
#    'et': 2,
#    'cetera': 2,
#    'americas': 1,
#    'reflections': 1,
#    'mirror': 1,
#    'does': 1,
#    'ar': 1}},
#  {'song': 'A-ap-rocky-fuckin-problems-lyrics',
#   'word_counts': {'chorus': 4,
#    '2': 5,
#    'chainz': 4,
#    'drake': 6,
#    'both': 4,
#    'aap': 3,
#    'rocky': 2,
#    'i': 49,
#    'love': 14,
#    'bad': 12,
#    'bitches': 15,
#    'thats': 13,
#    'my': 20,
#    'fuckin': 34,
#    'problem': 28,
#    'and': 16,
#    'yeah': 17,
#    'like': 21,
#    'to': 23,
#    'fuck': 13,
#    'got': 15,
#    'a': 25,
#    'if': 6,
#    'findin': 4,
#    'somebody': 4,
#    'real': 4,
#    'is': 7,
#    'your': 12,
#    'bring': 4,
#    'girls': 4,
#    'the': 24,
#    'crib': 4,
#    'maybe': 4,
#    'we': 6,
#    'can': 5,
#    'solve': 4,
#    'it': 11,
#    'ayy': 3,
#    'verse': 3,
#    '1': 1,
#    'hold': 1,
#    'up': 5,
#    'simmer': 1,
#    'down': 2,
#    'uh': 10,
#    'takin': 1,
#    'hella': 1,
#    'long': 2,
#    'bitch': 2,
#    'give': 1,
#    'me': 7,
#    'now': 2,
#    'make': 6,
#    'that': 4,
#    'thing': 1,
#    'pop': 1,
#    'semi': 1,
#    'or': 2,
#    '9': 1,
#    'ooh': 2,
#    'baby': 1,
#    'raw': 1,
#    'with': 1,
#    'shimmy': 2,
#    'ya': 2,
#    'huh': 1,
#    'get': 4,
#    'never': 1,
#    'met': 1,
#    'motherfucker': 2,
#    'fresh': 1,
#    'all': 5,
#    'these': 1,
#    'motherfuckers': 1,
#    'wanna': 1,
#    'dress': 1,
#    'but': 4,
#    'chrome': 1,
#    'dome': 1,
#    'you': 11,
#    'sweat': 1,
#    'keith': 1,
#    'cause': 1,
#    'im': 3,
#    'nigga': 9,
#    'how': 1,
#    'figure': 1,
#    'gettin': 2,
#    'figures': 1,
#    'she': 6,
#    'rollin': 1,
#    'swishers': 1,
#    'brought': 3,
#    'her': 3,
#    'niggas': 2,
#    'they': 2,
#    'bent': 1,
#    'off': 1,
#    'liquor': 1,
#    'licorice': 1,
#    'let': 1,
#    'lick': 1,
#    'alright': 1,
#    'say': 4,
#    'money': 1,
#    'act': 1,
#    'niggerish': 1,
#    'least': 1,
#    'rich': 1,
#    'be': 3,
#    'broads': 1,
#    'bored': 1,
#    'turn': 2,
#    'dyke': 1,
#    'out': 2,
#    'have': 2,
#    'boys': 1,
#    'beast': 3,
#    'know': 3,
#    'when': 1,
#    'this': 5,
#    'beat': 1,
#    'on': 9,
#    'think': 2,
#    'about': 2,
#    'of': 2,
#    'been': 2,
#    'leadin': 1,
#    'rappers': 1,
#    'ive': 1,
#    'feedin': 1,
#    'feelin': 1,
#    'same': 2,
#    'dudes': 1,
#    'speakin': 1,
#    'oh': 1,
#    'word': 1,
#    'aint': 3,
#    'heard': 1,
#    'album': 1,
#    'who': 1,
#    'sleepin': 1,
#    'should': 1,
#    'print': 1,
#    'lyrics': 1,
#    'readalong': 1,
#    'singalong': 1,
#    'less': 1,
#    'weed': 1,
#    'along': 1,
#    'then': 5,
#    'ju': 1,
#    'okay': 1,
#    'just': 2,
#    'drop': 1,
#    'eagle': 1,
#    'stare': 1,
#    'at': 2,
#    'stars': 1,
#    'put': 1,
#    'beatles': 1,
#    'shit': 1,
#    'talkin': 2,
#    'bout': 1,
#    'not': 1,
#    'for': 4,
#    'discussion': 1,
#    'will': 1,
#    'pay': 2,
#    'bigger': 1,
#    'dont': 6,
#    'no': 1,
#    'reduction': 1,
#    'its': 1,
#    'comin': 2,
#    'from': 2,
#    'trust': 1,
#    'head': 1,
#    'bustin': 1,
#    'yes': 1,
#    'lord': 1,
#    'really': 1,
#    'often': 1,
#    'longdick': 1,
#    '3': 1,
#    'kendrick': 2,
#    'lamar': 2,
#    'ho': 1,
#    'finale': 1,
#    'pep': 2,
#    'talk': 1,
#    'into': 1,
#    'rally': 1,
#    'hood': 1,
#    'live': 1,
#    'inside': 1,
#    'in': 3,
#    'valley': 1,
#    'vacad': 1,
#    'atlanta': 1,
#    'goin': 1,
#    'back': 2,
#    'cali': 1,
#    'mmm': 2,
#    'girl': 3,
#    'line': 2,
#    'world': 1,
#    'irony': 1,
#    'em': 2,
#    'damn': 1,
#    'time': 1,
#    'eyein': 1,
#    'exist': 1,
#    'want': 1,
#    'dick': 1,
#    'aka': 1,
#    'benz': 1,
#    'car': 1,
#    'mean': 1,
#    'friendses': 1,
#    'need': 1,
#    'par': 1,
#    'see': 1,
#    'standards': 1,
#    'are': 1,
#    'pampered': 1,
#    'by': 2,
#    'threesomes': 1,
#    'tomorrow': 1,
#    'kill': 1,
#    'dead': 1,
#    'bodies': 1,
#    'hallway': 1,
#    'involved': 1,
#    'listen': 1,
#    'what': 1,
#    'crystal': 1,
#    'ball': 1,
#    'halle': 1,
#    'berry': 1,
#    'hallelujah': 1,
#    'holla': 1,
#    'ill': 1,
#    'do': 1,
#    'produced': 1,
#    '40': 1}},
#  {'song': 'Kendrick-lamar-dna-lyrics',
#   'word_counts': {'verse': 2,
#    '1': 2,
#    'i': 39,
#    'got': 25,
#    'loyalty': 4,
#    'royalty': 4,
#    'inside': 14,
#    'my': 19,
#    'dna': 19,
#    'cocaine': 1,
#    'quarter': 1,
#    'piece': 1,
#    'war': 1,
#    'and': 13,
#    'peace': 2,
#    'power': 2,
#    'poison': 1,
#    'pain': 1,
#    'joy': 1,
#    'hustle': 1,
#    'though': 1,
#    'ambition': 1,
#    'flow': 1,
#    'was': 4,
#    'born': 3,
#    'like': 7,
#    'this': 10,
#    'since': 1,
#    'one': 1,
#    'immaculate': 1,
#    'conception': 1,
#    'transform': 1,
#    'perform': 1,
#    'yeshua': 1,
#    'new': 1,
#    'weapon': 1,
#    'dont': 5,
#    'contemplate': 1,
#    'meditate': 1,
#    'then': 2,
#    'off': 2,
#    'your': 11,
#    'fucking': 1,
#    'head': 1,
#    'that': 6,
#    'putthekidstobed': 1,
#    'realness': 1,
#    'just': 4,
#    'kill': 1,
#    'shit': 5,
#    'cause': 1,
#    'its': 1,
#    'in': 12,
#    'millions': 1,
#    'riches': 1,
#    'buildin': 2,
#    'dark': 1,
#    'evil': 1,
#    'rot': 1,
#    'troublesome': 1,
#    'heart': 1,
#    'win': 2,
#    'again': 3,
#    'wimbledon': 1,
#    'serve': 1,
#    'yeah': 5,
#    'thats': 1,
#    'him': 1,
#    'the': 31,
#    'sound': 1,
#    'engine': 1,
#    'is': 7,
#    'a': 13,
#    'bird': 1,
#    'you': 13,
#    'see': 3,
#    'fireworks': 1,
#    'corvette': 1,
#    'tire': 1,
#    'skrrt': 1,
#    'boulevard': 1,
#    'know': 3,
#    'how': 2,
#    'work': 2,
#    'who': 1,
#    'are': 3,
#    'yous': 3,
#    'bitch': 1,
#    'hormones': 1,
#    'prolly': 3,
#    'switch': 1,
#    'problem': 1,
#    'all': 4,
#    'sucker': 1,
#    'daddy': 1,
#    'snitched': 1,
#    'heritage': 2,
#    'backbone': 1,
#    'exist': 1,
#    'outside': 1,
#    'jellyfish': 1,
#    'gauge': 1,
#    'pedigree': 1,
#    'most': 1,
#    'definitely': 1,
#    'tolerate': 1,
#    'front': 1,
#    'ive': 3,
#    'been': 2,
#    'through': 2,
#    'offend': 1,
#    'paulas': 1,
#    'oldest': 1,
#    'son': 1,
#    'murder': 1,
#    'conviction': 1,
#    'burners': 1,
#    'boosters': 1,
#    'burglars': 1,
#    'ballers': 1,
#    'dead': 2,
#    'redemption': 1,
#    'scholars': 1,
#    'fathers': 1,
#    'with': 1,
#    'kids': 1,
#    'wish': 1,
#    'fed': 1,
#    'forgiveness': 1,
#    'soldiers': 2,
#    'im': 5,
#    'beast': 1,
#    'expertise': 1,
#    'checked': 1,
#    'out': 2,
#    'second': 1,
#    'grade': 1,
#    'when': 4,
#    '9': 2,
#    'on': 13,
#    'cell': 1,
#    'motel': 1,
#    'we': 1,
#    'didnt': 1,
#    'have': 1,
#    'nowhere': 1,
#    'to': 9,
#    'stay': 1,
#    'at': 2,
#    '29': 1,
#    'done': 2,
#    'so': 1,
#    'well': 1,
#    'hit': 2,
#    'cartwheel': 1,
#    'estate': 1,
#    'gon': 2,
#    'shine': 1,
#    'supposed': 1,
#    'antisocial': 1,
#    'extrovert': 1,
#    'excellent': 1,
#    'mean': 1,
#    'extra': 1,
#    'absentness': 1,
#    'what': 2,
#    'fuck': 3,
#    'heard': 1,
#    'pessimists': 1,
#    'never': 2,
#    'struck': 1,
#    'nerve': 1,
#    'nazareth': 1,
#    'plead': 1,
#    'his': 1,
#    'case': 1,
#    'reason': 1,
#    'powers': 1,
#    'here': 1,
#    'earth': 1,
#    'salute': 1,
#    'truth': 1,
#    'prophet': 1,
#    'say': 2,
#    'bridge': 1,
#    'kendrick': 1,
#    'lamar': 1,
#    'geraldo': 1,
#    'rivera': 1,
#    'ii': 1,
#    'why': 1,
#    'hip': 1,
#    'hop': 1,
#    'has': 1,
#    'more': 1,
#    'damage': 1,
#    'young': 1,
#    'african': 1,
#    'americans': 1,
#    'than': 2,
#    'racism': 1,
#    'recent': 1,
#    'years': 1,
#    'live': 2,
#    'better': 1,
#    'life': 3,
#    'rollin': 1,
#    'several': 1,
#    'dice': 1,
#    'be': 4,
#    '5': 1,
#    '4': 1,
#    '3': 1,
#    '2': 2,
#    'inheritin': 1,
#    'money': 3,
#    'mecca': 1,
#    'of': 1,
#    'marriages': 1,
#    'tell': 3,
#    'me': 3,
#    'somethin': 1,
#    'mothafuckas': 1,
#    'cant': 1,
#    'nothin': 1,
#    'id': 1,
#    'rather': 1,
#    'die': 1,
#    'listen': 1,
#    'not': 1,
#    'for': 1,
#    'imitation': 1,
#    'an': 1,
#    'abomination': 1,
#    'it': 3,
#    'matrix': 1,
#    'dodgin': 2,
#    'bullets': 1,
#    'reapin': 1,
#    'sow': 1,
#    'stackin': 1,
#    'up': 2,
#    'footage': 1,
#    'livin': 1,
#    'go': 1,
#    'sleepin': 1,
#    'villa': 1,
#    'sippin': 1,
#    'from': 1,
#    'grammy': 1,
#    'walkin': 1,
#    'diamond': 1,
#    'ceilin': 1,
#    'marble': 1,
#    'floors': 1,
#    'beach': 1,
#    'window': 2,
#    'peekin': 1,
#    'baby': 1,
#    'pool': 1,
#    'godfather': 1,
#    'goals': 1,
#    'only': 1,
#    'lord': 1,
#    'knows': 1,
#    'goin': 1,
#    'hammer': 1,
#    'paparazzi': 1,
#    'freakin': 1,
#    'cameras': 1,
#    'eat': 1,
#    'four': 1,
#    'daughters': 1,
#    'brock': 1,
#    'wearin': 1,
#    'sandals': 1,
#    'yoga': 1,
#    'monday': 1,
#    'stretchin': 1,
#    'nirvana': 1,
#    'watchin': 1,
#    'snakes': 1,
#    'curvin': 1,
#    'fakes': 1,
#    'phone': 1,
#    'conversate': 1,
#    'compromise': 1,
#    'penetrate': 1,
#    'sex': 2,
#    'murderthese': 1,
#    'breaks': 1,
#    'these': 1,
#    'times': 1,
#    'level': 1,
#    'number': 1,
#    'look': 1,
#    'sky': 1,
#    '10': 1,
#    'way': 4,
#    'sentence': 1,
#    'killings': 1,
#    'motherfucker': 1,
#    'winners': 1,
#    'aint': 4,
#    'without': 2,
#    'body': 1,
#    'belt': 1,
#    'ticket': 1,
#    'plate': 1,
#    'sick': 1,
#    'enough': 2,
#    'pull': 1,
#    'yourself': 1,
#    'rich': 1,
#    'lot': 1,
#    'skate': 1,
#    'destruction': 1,
#    'gonna': 3,
#    'fate': 2,
#    'our': 1,
#    'faith': 1,
#    'world': 1,
#    'let': 1,
#    'rotate': 1,
#    'murderour': 1,
#    'video': 1,
#    'outro': 1}},
#  {'song': 'Kendrick-lamar-poetic-justice-lyrics',
#   'word_counts': {'produced': 1,
#    'by': 1,
#    'scoop': 1,
#    'deville': 1,
#    'sounwave': 1,
#    'intro': 1,
#    'kendrick': 6,
#    'lamar': 6,
#    'every': 4,
#    'second': 1,
#    'minute': 1,
#    'man': 2,
#    'i': 36,
#    'swear': 1,
#    'that': 15,
#    'she': 3,
#    'can': 27,
#    'get': 23,
#    'it': 37,
#    'say': 4,
#    'if': 4,
#    'you': 62,
#    'a': 21,
#    'bad': 1,
#    'bitch': 1,
#    'put': 9,
#    'your': 14,
#    'hands': 3,
#    'up': 9,
#    'high': 4,
#    'tell': 6,
#    'em': 3,
#    'dim': 1,
#    'the': 10,
#    'lights': 1,
#    'down': 3,
#    'right': 4,
#    'now': 1,
#    'me': 7,
#    'in': 19,
#    'mood': 2,
#    'im': 5,
#    'talkin': 3,
#    'about': 1,
#    'dark': 3,
#    'room': 3,
#    'perfume': 1,
#    'go': 5,
#    'verse': 3,
#    '1': 1,
#    'recognize': 1,
#    'fragrance': 1,
#    'hold': 1,
#    'aint': 2,
#    'never': 3,
#    'gotta': 1,
#    'shit': 1,
#    'uh': 2,
#    'and': 21,
#    'know': 27,
#    'taste': 1,
#    'is': 8,
#    'little': 2,
#    'bit': 1,
#    'hmm': 1,
#    'maintenance': 1,
#    'everybody': 1,
#    'else': 1,
#    'basic': 1,
#    'live': 1,
#    'life': 3,
#    'on': 3,
#    'an': 1,
#    'everyday': 1,
#    'basis': 1,
#    'with': 5,
#    'poetic': 11,
#    'justice': 11,
#    'told': 2,
#    'flower': 2,
#    'bloomed': 2,
#    'would': 4,
#    'trust': 2,
#    'mean': 4,
#    'write': 5,
#    'poems': 2,
#    'these': 6,
#    'songs': 2,
#    'dedicated': 2,
#    'to': 7,
#    'when': 6,
#    'youre': 2,
#    'for': 8,
#    'empathy': 1,
#    'theres': 1,
#    'blood': 1,
#    'my': 6,
#    'pen': 1,
#    'better': 1,
#    'yet': 1,
#    'where': 9,
#    'friends': 1,
#    'really': 3,
#    'wanna': 4,
#    'all': 4,
#    'show': 1,
#    'off': 1,
#    'fuck': 1,
#    'pour': 1,
#    'plenty': 1,
#    'of': 2,
#    'champagne': 1,
#    'cold': 1,
#    'nights': 1,
#    'curse': 1,
#    'this': 8,
#    'name': 1,
#    'called': 2,
#    'girlfriends': 1,
#    'yall': 1,
#    'curled': 1,
#    'bitty': 1,
#    'range': 1,
#    'heard': 1,
#    'party': 2,
#    'nigga': 3,
#    'dont': 5,
#    'approach': 1,
#    'her': 1,
#    'atari': 1,
#    'good': 2,
#    'game': 2,
#    'homie': 5,
#    'sorry': 2,
#    'they': 3,
#    'conversation': 1,
#    'rule': 1,
#    'nation': 1,
#    'but': 3,
#    'could': 2,
#    'wrongs': 2,
#    'less': 2,
#    'real': 2,
#    'ps': 3,
#    'chorus': 3,
#    'just': 29,
#    'what': 7,
#    'want': 6,
#    'song': 5,
#    'alright': 5,
#    '2': 1,
#    'drake': 1,
#    'hope': 1,
#    'play': 1,
#    'cause': 1,
#    'ol': 1,
#    'girl': 2,
#    'test': 1,
#    'patience': 1,
#    'seductive': 1,
#    'photographs': 1,
#    'oneoff': 1,
#    'vacations': 1,
#    'youve': 1,
#    'been': 1,
#    'takin': 1,
#    'clearly': 1,
#    'lot': 1,
#    'take': 2,
#    'make': 1,
#    'sense': 1,
#    'young': 1,
#    'east': 1,
#    'african': 1,
#    'too': 1,
#    'busy': 1,
#    'fuckin': 1,
#    'other': 1,
#    'was': 2,
#    'tryna': 1,
#    'plane': 1,
#    'momma': 1,
#    'motherland': 1,
#    'do': 2,
#    'maybe': 2,
#    'one': 2,
#    'day': 1,
#    'figure': 2,
#    'out': 5,
#    'gonna': 1,
#    'need': 3,
#    'someone': 1,
#    'its': 5,
#    'here': 3,
#    'city': 1,
#    'run': 1,
#    'from': 6,
#    'we': 6,
#    'come': 1,
#    'sound': 1,
#    'like': 2,
#    'were': 1,
#    'so': 1,
#    'new': 1,
#    'goddamn': 1,
#    'got': 1,
#    'adjusted': 1,
#    'fun': 1,
#    'sex': 2,
#    'natural': 1,
#    'hair': 1,
#    'soft': 1,
#    'skin': 1,
#    'big': 1,
#    'ass': 1,
#    'sundress': 1,
#    'ooh': 1,
#    'god': 1,
#    'doin': 1,
#    'walk': 1,
#    'see': 2,
#    'thing': 1,
#    'move': 1,
#    'wish': 1,
#    'fight': 1,
#    'talk': 1,
#    'more': 2,
#    'communication': 1,
#    'save': 1,
#    'relations': 1,
#    'unless': 1,
#    '3': 1,
#    'time': 2,
#    'words': 1,
#    'become': 1,
#    'taboo': 1,
#    'makin': 1,
#    'sure': 1,
#    'punctuation': 1,
#    'curve': 1,
#    'letter': 1,
#    'heres': 1,
#    'true': 1,
#    'livin': 1,
#    'margin': 1,
#    'metaphor': 1,
#    'proof': 1,
#    'hear': 3,
#    'love': 3,
#    'not': 3,
#    'verb': 3,
#    'lookin': 2,
#    'mirror': 1,
#    'call': 1,
#    'crazy': 1,
#    'both': 1,
#    'be': 1,
#    'insane': 1,
#    'fatal': 1,
#    'attraction': 1,
#    'common': 2,
#    'have': 1,
#    'pain': 1,
#    'power': 1,
#    'steerin': 1,
#    'drive': 1,
#    'swerve': 1,
#    'interference': 1,
#    'coherent': 1,
#    'uhhuh': 2,
#    'thats': 1,
#    'heartbeat': 1,
#    'either': 1,
#    'caught': 1,
#    'or': 4,
#    'read': 1,
#    'slow': 1,
#    'youll': 1,
#    'find': 1,
#    'gold': 1,
#    'mines': 1,
#    'lines': 1,
#    'sincerely': 1,
#    'yours': 1,
#    'truly': 1,
#    'before': 2,
#    'blind': 1,
#    'outro': 1,
#    'skit': 1,
#    'gon': 3,
#    'ask': 1,
#    'problem': 1,
#    'ayy': 1,
#    'over': 2,
#    'sherane': 1,
#    'yo': 1,
#    'care': 1,
#    'who': 1,
#    'he': 2,
#    'wrap': 1,
#    'hol': 3,
#    'okay': 4,
#    'ima': 1,
#    'grandma': 1,
#    'stay': 3,
#    'mama': 1,
#    'daddy': 1,
#    'enough': 1,
#    'matter': 1,
#    'fact': 1,
#    'van': 1,
#    'car': 1,
#    'snatch': 1,
#    'motherfucker': 1}},
#  {'song': 'Kendrick-lamar-bitch-dont-kill-my-vibe-lyrics',
#   'word_counts': {'produced': 1,
#    'by': 1,
#    'sounwave': 1,
#    'chorus': 3,
#    'i': 40,
#    'am': 3,
#    'a': 26,
#    'sinner': 3,
#    'whos': 3,
#    'probably': 3,
#    'gonna': 3,
#    'sin': 3,
#    'again': 4,
#    'lord': 6,
#    'forgive': 6,
#    'me': 20,
#    'things': 3,
#    'dont': 30,
#    'understand': 3,
#    'sometimes': 3,
#    'need': 3,
#    'to': 15,
#    'be': 6,
#    'alone': 3,
#    'bitch': 25,
#    'kill': 25,
#    'my': 40,
#    'vibe': 25,
#    'can': 22,
#    'feel': 9,
#    'your': 8,
#    'energy': 3,
#    'from': 3,
#    'two': 4,
#    'planets': 3,
#    'away': 3,
#    'got': 9,
#    'drink': 4,
#    'music': 4,
#    'would': 3,
#    'share': 3,
#    'it': 8,
#    'but': 4,
#    'today': 3,
#    'im': 5,
#    'yelling': 3,
#    'verse': 2,
#    '1': 1,
#    'look': 3,
#    'inside': 2,
#    'of': 7,
#    'soul': 2,
#    'and': 16,
#    'you': 22,
#    'find': 2,
#    'gold': 1,
#    'maybe': 1,
#    'get': 3,
#    'rich': 1,
#    'out': 5,
#    'never': 1,
#    'exist': 1,
#    'the': 17,
#    'changes': 3,
#    'new': 4,
#    'life': 2,
#    'always': 1,
#    'knew': 1,
#    'dangerous': 1,
#    'say': 4,
#    'that': 6,
#    'like': 4,
#    'challenge': 1,
#    'tell': 3,
#    'its': 2,
#    'painless': 1,
#    'know': 5,
#    'what': 4,
#    'pain': 1,
#    'is': 8,
#    'how': 1,
#    'paint': 1,
#    'this': 8,
#    'picture': 1,
#    'when': 1,
#    'color': 1,
#    'blind': 1,
#    'hangin': 1,
#    'with': 4,
#    'fell': 1,
#    'on': 9,
#    'face': 1,
#    'awoke': 1,
#    'scar': 1,
#    'another': 1,
#    'mistake': 1,
#    'livin': 2,
#    'deep': 1,
#    'in': 11,
#    'heart': 1,
#    'wear': 1,
#    'top': 1,
#    'sleeve': 1,
#    'flick': 1,
#    'admit': 1,
#    'did': 1,
#    'yours': 1,
#    'why': 1,
#    'resent': 1,
#    'every': 3,
#    'making': 1,
#    'purpose': 1,
#    'petty': 1,
#    'even': 2,
#    'small': 2,
#    'lighter': 2,
#    'burn': 2,
#    'bridge': 2,
#    'refrain': 2,
#    'people': 3,
#    'around': 2,
#    'just': 2,
#    'want': 2,
#    'famous': 2,
#    'see': 4,
#    'city': 2,
#    'found': 2,
#    'then': 4,
#    'put': 3,
#    'stages': 2,
#    'thats': 4,
#    'amazin': 2,
#    'quick': 2,
#    'check': 2,
#    'all': 3,
#    'disrespect': 2,
#    'let': 3,
#    '2': 1,
#    'tryin': 2,
#    'keep': 2,
#    'alive': 2,
#    'not': 1,
#    'compromise': 1,
#    'feeling': 3,
#    'we': 4,
#    'love': 1,
#    'youre': 1,
#    'deprived': 1,
#    'only': 1,
#    'cosign': 1,
#    'radio': 1,
#    'does': 1,
#    'lookin': 1,
#    'right': 1,
#    'past': 1,
#    'live': 3,
#    'world': 3,
#    'different': 1,
#    'axles': 1,
#    'behind': 1,
#    'mirror': 1,
#    'scared': 1,
#    'emotions': 1,
#    'inferior': 1,
#    'shit': 2,
#    'vital': 2,
#    'had': 2,
#    'die': 1,
#    'pitiful': 1,
#    'vain': 1,
#    'watch': 1,
#    'chain': 1,
#    'way': 1,
#    'more': 1,
#    'believable': 1,
#    'give': 1,
#    'feasible': 1,
#    'gain': 1,
#    'rather': 1,
#    'seasonal': 1,
#    'name': 1,
#    'ill': 2,
#    'somethin': 1,
#    'blame': 1,
#    'yourselves': 1,
#    'remain': 1,
#    'stuck': 1,
#    'box': 1,
#    'ima': 2,
#    'break': 2,
#    'hide': 4,
#    'lock': 2,
#    'outro': 2,
#    'aint': 1,
#    'heard': 1,
#    'coast': 1,
#    'long': 2,
#    'time': 1,
#    'line': 1,
#    'they': 2,
#    'waiting': 1,
#    'kendrick': 1,
#    'first': 1,
#    'fifteenth': 1,
#    'threes': 1,
#    'air': 1,
#    'are': 1,
#    'sync': 1,
#    'feelings': 2,
#    'now': 1,
#    'better': 1,
#    'do': 1,
#    'take': 1,
#    'girlfriend': 1,
#    'pussy': 1,
#    'pedestal': 1,
#    'walk': 1,
#    'door': 1,
#    'scream': 1,
#    'years': 1,
#    'resolution': 1,
#    'stop': 1,
#    'pollution': 1,
#    'talk': 1,
#    'too': 1,
#    'motherfuckin': 1,
#    'much': 1,
#    'death': 1,
#    'molly': 1,
#    'ayy': 1,
#    'kdot': 1,
#    'car': 1,
#    'nigga': 2,
#    'come': 1,
#    'finna': 1,
#    'roll': 1,
#    'pack': 1,
#    'blacks': 1,
#    'beat': 1,
#    'cd': 1,
#    'yo': 1,
#    'freestyles': 1,
#    'ready': 1}},
#  {'song': 'Kendrick-lamar-king-kunta-lyrics',
#   'word_counts': {'produced': 1,
#    'by': 3,
#    'sounwave': 1,
#    'additional': 1,
#    'production': 1,
#    'terrace': 1,
#    'martin': 1,
#    'intro': 1,
#    'kendrick': 10,
#    'lamar': 10,
#    'i': 35,
#    'got': 12,
#    'a': 14,
#    'bone': 1,
#    'to': 9,
#    'pick': 1,
#    'dont': 1,
#    'want': 11,
#    'you': 28,
#    'monkeymouth': 1,
#    'motherfuckers': 1,
#    'sittin': 1,
#    'in': 6,
#    'my': 6,
#    'throne': 1,
#    'again': 1,
#    'ayy': 2,
#    'nigga': 3,
#    'whats': 1,
#    'happenin': 1,
#    'kdot': 1,
#    'back': 2,
#    'the': 63,
#    'hood': 2,
#    'im': 3,
#    'mad': 2,
#    'he': 1,
#    'but': 5,
#    'aint': 3,
#    'stressin': 1,
#    'true': 1,
#    'friends': 1,
#    'one': 1,
#    'question': 1,
#    'chorus': 4,
#    '1': 4,
#    'bitch': 8,
#    'where': 8,
#    'when': 12,
#    'was': 12,
#    'walkin': 9,
#    'now': 12,
#    'run': 9,
#    'game': 8,
#    'whole': 8,
#    'world': 9,
#    'talkin': 8,
#    'king': 12,
#    'kunta': 12,
#    'everybody': 8,
#    'wanna': 8,
#    'cut': 8,
#    'legs': 8,
#    'off': 9,
#    'him': 9,
#    'black': 4,
#    'man': 4,
#    'taking': 4,
#    'no': 5,
#    'losses': 4,
#    'oh': 10,
#    'yeah': 8,
#    'yamswhats': 2,
#    'yams': 2,
#    'verse': 3,
#    'yam': 2,
#    'is': 2,
#    'power': 1,
#    'that': 2,
#    'be': 4,
#    'can': 4,
#    'smell': 1,
#    'it': 8,
#    'down': 1,
#    'street': 1,
#    'yes': 2,
#    'we': 10,
#    'dig': 1,
#    'rappin': 1,
#    'rapper': 1,
#    'with': 4,
#    'ghost': 1,
#    'writer': 1,
#    'what': 1,
#    'fuck': 2,
#    'happened': 1,
#    'swore': 1,
#    'wouldnt': 1,
#    'tell': 1,
#    'most': 1,
#    'of': 3,
#    'yall': 1,
#    'sharing': 1,
#    'bars': 1,
#    'like': 1,
#    'bottom': 2,
#    'bunk': 1,
#    'twoman': 2,
#    'cell': 2,
#    'somethings': 2,
#    'water': 2,
#    'and': 6,
#    'if': 6,
#    'gotta': 1,
#    'brownnose': 1,
#    'for': 2,
#    'some': 1,
#    'gold': 2,
#    'then': 1,
#    'id': 1,
#    'rather': 1,
#    'bum': 1,
#    'than': 1,
#    'motherfuckin': 2,
#    'baller': 1,
#    '2': 2,
#    'brought': 1,
#    'out': 2,
#    'richard': 1,
#    'pryor': 1,
#    'manipulated': 1,
#    'bill': 1,
#    'clinton': 1,
#    'desires': 1,
#    '247': 1,
#    '365': 1,
#    'days': 1,
#    'times': 1,
#    'two': 1,
#    'contemplatin': 1,
#    'gettin': 1,
#    'stage': 1,
#    'just': 1,
#    'go': 2,
#    'see': 1,
#    'enemy': 1,
#    'say': 1,
#    '3': 1,
#    'goatmouth': 1,
#    'mammyfucker': 1,
#    'gonna': 1,
#    'kill': 1,
#    'couple': 1,
#    'rappers': 1,
#    'they': 2,
#    'did': 1,
#    'themselves': 1,
#    'everybodys': 2,
#    'suicidal': 1,
#    'even': 1,
#    'need': 1,
#    'help': 1,
#    'this': 2,
#    'shit': 2,
#    'elementary': 1,
#    'ill': 1,
#    'probably': 2,
#    'jail': 1,
#    'shoot': 1,
#    'at': 1,
#    'your': 2,
#    'identity': 1,
#    'bounce': 1,
#    'left': 1,
#    'stuck': 1,
#    'flag': 1,
#    'city': 1,
#    'screamin': 2,
#    'compton': 1,
#    'should': 1,
#    'mayor': 1,
#    'done': 1,
#    'honest': 1,
#    'put': 1,
#    'on': 1,
#    'momma': 1,
#    'baby': 1,
#    'boo': 1,
#    'too': 1,
#    '20': 1,
#    'million': 1,
#    'court': 1,
#    'buildin': 1,
#    'woowoo': 1,
#    'aw': 1,
#    'judge': 1,
#    'made': 1,
#    'past': 1,
#    '25': 1,
#    'there': 1,
#    'little': 1,
#    'nappyheaded': 1,
#    'behind': 1,
#    'life': 1,
#    'fat': 1,
#    'vagina': 1,
#    'annie': 2,
#    'are': 2,
#    'okay': 2,
#    'limo': 1,
#    'tinted': 1,
#    'plates': 1,
#    'straight': 1,
#    'from': 2,
#    'belly': 1,
#    'beast': 1,
#    'peasant': 1,
#    'prince': 1,
#    'walkingunshot': 1,
#    'time': 1,
#    'hear': 1,
#    'next': 1,
#    'pop': 1,
#    'funk': 26,
#    'shall': 1,
#    'within': 1,
#    'yougunshot': 1,
#    'outro': 1,
#    'whitney': 1,
#    'alford': 1,
#    'give': 4,
#    'gon': 4,
#    'take': 4,
#    'do': 2,
#    'poem': 1,
#    'remember': 1,
#    'conflicted': 1,
#    'misusing': 1,
#    'influence': 1}},
#  {'song': 'Kendrick-lamar-element-lyrics',
#   'word_counts': {'intro': 1,
#    'kid': 3,
#    'capri': 3,
#    'kendrick': 2,
#    'lamar': 2,
#    'new': 1,
#    'kung': 1,
#    'fu': 1,
#    'kenny': 1,
#    'aint': 5,
#    'nobody': 2,
#    'prayin': 2,
#    'for': 14,
#    'me': 11,
#    'yall': 11,
#    'know': 7,
#    'what': 1,
#    'happens': 1,
#    'on': 12,
#    'earth': 2,
#    'stays': 1,
#    'here': 1,
#    'we': 6,
#    'go': 8,
#    'i': 28,
#    'dont': 9,
#    'give': 5,
#    'a': 19,
#    'fuck': 3,
#    'verse': 3,
#    '1': 1,
#    'im': 4,
#    'willin': 2,
#    'to': 8,
#    'die': 2,
#    'this': 7,
#    'shit': 7,
#    'done': 1,
#    'cried': 1,
#    'might': 1,
#    'take': 9,
#    'life': 4,
#    'put': 1,
#    'the': 19,
#    'bible': 1,
#    'down': 1,
#    'and': 9,
#    'eye': 2,
#    'an': 2,
#    'dot': 1,
#    'my': 14,
#    'enemy': 1,
#    'wont': 5,
#    'catch': 1,
#    'vibe': 1,
#    'ayy': 7,
#    'been': 3,
#    'stomped': 1,
#    'out': 15,
#    'in': 6,
#    'front': 2,
#    'of': 10,
#    'mama': 1,
#    'daddy': 1,
#    'commissary': 1,
#    'made': 4,
#    'it': 13,
#    'commas': 1,
#    'bitch': 6,
#    'all': 4,
#    'grandmas': 1,
#    'dead': 1,
#    'so': 1,
#    'your': 4,
#    'head': 1,
#    'thirty': 1,
#    'millions': 1,
#    'later': 1,
#    'feds': 1,
#    'watchin': 1,
#    'auntie': 1,
#    'telegram': 1,
#    'like': 1,
#    'be': 6,
#    'cautious': 1,
#    'hangin': 1,
#    'at': 2,
#    'tams': 1,
#    'stockton': 1,
#    'do': 3,
#    'gram': 1,
#    'compton': 1,
#    'nigga': 7,
#    'ill': 1,
#    'fuckin': 2,
#    'goin': 2,
#    'back': 1,
#    'broke': 1,
#    'family': 1,
#    'sellin': 1,
#    'dope': 1,
#    'thats': 4,
#    'why': 1,
#    'you': 6,
#    'maneyass': 1,
#    'rap': 1,
#    'niggas': 4,
#    'better': 1,
#    'chorus': 3,
#    'if': 9,
#    'gotta': 7,
#    'slap': 3,
#    'pussyass': 3,
#    'ima': 6,
#    'make': 6,
#    'look': 10,
#    'sexy': 9,
#    'hard': 3,
#    'pull': 3,
#    'up': 3,
#    'hop': 3,
#    'air': 3,
#    'they': 8,
#    'element': 6,
#    'nah': 3,
#    '2': 1,
#    'allergic': 1,
#    'imaginary': 1,
#    'rich': 1,
#    'seven': 1,
#    'figures': 1,
#    'ho': 1,
#    'slimmer': 1,
#    'than': 1,
#    'figure': 1,
#    'digital': 1,
#    'physical': 1,
#    'bunch': 1,
#    'criminals': 1,
#    'money': 1,
#    'phone': 1,
#    'calls': 1,
#    'okay': 1,
#    'let': 1,
#    'a1': 1,
#    'fly': 1,
#    'relocate': 1,
#    'jump': 1,
#    'same': 2,
#    'g5': 1,
#    'checkin': 1,
#    'heavy': 1,
#    'cause': 2,
#    'yeah': 8,
#    'never': 2,
#    'ready': 1,
#    '100k': 1,
#    'spread': 1,
#    'across': 1,
#    'floor': 2,
#    'cross': 1,
#    'none': 1,
#    'with': 1,
#    'flow': 2,
#    'years': 1,
#    'makin': 1,
#    'mistake': 1,
#    'got': 1,
#    'em': 1,
#    'by': 1,
#    'landslide': 1,
#    'talkin': 1,
#    'about': 1,
#    'races': 1,
#    'thisll': 1,
#    'tie': 1,
#    'just': 4,
#    'laces': 1,
#    'careers': 1,
#    'off': 1,
#    'patient': 1,
#    'mr': 1,
#    'one': 2,
#    'through': 1,
#    'five': 1,
#    'only': 3,
#    'logic': 1,
#    'fake': 1,
#    'death': 1,
#    'cuba': 1,
#    'option': 1,
#    'bridge': 1,
#    'damned': 1,
#    'yuh': 2,
#    'goddamn': 3,
#    'us': 1,
#    'damn': 3,
#    'its': 4,
#    'shame': 1,
#    'line': 1,
#    'get': 2,
#    'way': 1,
#    '3': 1,
#    'thought': 2,
#    'wasnt': 1,
#    'gonna': 1,
#    'see': 3,
#    'huh': 4,
#    'that': 2,
#    'kdot': 1,
#    'real': 2,
#    'was': 1,
#    'tv': 1,
#    'wanna': 1,
#    'flex': 1,
#    'la': 1,
#    'free': 1,
#    'next': 1,
#    'time': 1,
#    'hit': 1,
#    '10': 1,
#    'freeway': 1,
#    'need': 1,
#    'receipt': 1,
#    'most': 7,
#    'gon': 1,
#    'squeal': 1,
#    'envy': 1,
#    'but': 2,
#    'jealousy': 1,
#    'killed': 1,
#    'throw': 1,
#    'rocks': 1,
#    'try': 1,
#    'hide': 1,
#    'hand': 1,
#    'say': 1,
#    'his': 1,
#    'name': 1,
#    'promise': 1,
#    'youll': 1,
#    'candyman': 1,
#    'because': 1,
#    'eyes': 1,
#    'tell': 1,
#    'lies': 1,
#    'fade': 1,
#    'advised': 1,
#    'last': 1,
#    'lp': 1,
#    'tried': 1,
#    'lift': 1,
#    'black': 2,
#    'artists': 3,
#    'difference': 1,
#    'tween': 1,
#    'wack': 1,
#    'worlds': 1,
#    'greatest': 1}},
#  {'song': 'Kendrick-lamar-the-blacker-the-berry-lyrics',
#   'word_counts': {'produced': 1,
#    'by': 1,
#    'boi1da': 1,
#    'koz': 1,
#    'intro': 1,
#    'kendrick': 7,
#    'lamar': 7,
#    'lalah': 1,
#    'hathaway': 1,
#    'everything': 6,
#    'black': 29,
#    'i': 39,
#    'dont': 9,
#    'want': 8,
#    'they': 7,
#    'us': 2,
#    'to': 13,
#    'bow': 1,
#    'aint': 3,
#    'need': 3,
#    'down': 1,
#    'our': 2,
#    'knees': 1,
#    'some': 2,
#    'white': 1,
#    'mean': 5,
#    'and': 13,
#    'pray': 1,
#    'the': 53,
#    'god': 1,
#    'we': 13,
#    'believe': 1,
#    'all': 5,
#    'things': 1,
#    'eyes': 2,
#    'own': 2,
#    'bridge': 1,
#    'six': 1,
#    'in': 8,
#    'morn': 1,
#    'fire': 1,
#    'street': 2,
#    'burn': 2,
#    'baby': 1,
#    'thats': 3,
#    'wanna': 1,
#    'see': 4,
#    'sometimes': 1,
#    'get': 3,
#    'off': 1,
#    'watchin': 2,
#    'you': 30,
#    'die': 1,
#    'vain': 1,
#    'its': 8,
#    'such': 1,
#    'a': 20,
#    'shame': 1,
#    'may': 2,
#    'call': 1,
#    'me': 26,
#    'crazy': 1,
#    'say': 6,
#    'suffer': 1,
#    'from': 7,
#    'schizophrenia': 1,
#    'or': 6,
#    'somethin': 1,
#    'but': 5,
#    'homie': 1,
#    'made': 3,
#    'crack': 1,
#    'my': 19,
#    'nigga': 4,
#    'verse': 3,
#    '1': 1,
#    'im': 15,
#    'biggest': 3,
#    'hypocrite': 4,
#    'of': 16,
#    '2015': 3,
#    'once': 2,
#    'finish': 3,
#    'this': 9,
#    'witnesses': 2,
#    'will': 3,
#    'convey': 2,
#    'just': 5,
#    'what': 4,
#    'been': 1,
#    'feeling': 1,
#    'way': 1,
#    'since': 1,
#    'was': 2,
#    '16': 1,
#    'came': 2,
#    'senses': 1,
#    'never': 1,
#    'liked': 1,
#    'anyway': 1,
#    'fuck': 3,
#    'your': 5,
#    'friendship': 1,
#    'meant': 2,
#    'it': 3,
#    'africanamerican': 2,
#    'african': 2,
#    'as': 8,
#    'moon': 1,
#    'heritage': 1,
#    'small': 1,
#    'village': 1,
#    'pardon': 1,
#    'residence': 1,
#    'bottom': 1,
#    'mankind': 1,
#    'hair': 1,
#    'is': 7,
#    'nappy': 1,
#    'dick': 1,
#    'big': 6,
#    'nose': 1,
#    'round': 1,
#    'wide': 1,
#    'hate': 7,
#    'people': 2,
#    'plan': 1,
#    'terminate': 1,
#    'culture': 1,
#    'youre': 3,
#    'fuckin': 2,
#    'evil': 1,
#    'recognize': 1,
#    'that': 7,
#    'proud': 1,
#    'monkey': 1,
#    'vandalize': 1,
#    'perception': 1,
#    'cant': 1,
#    'take': 1,
#    'style': 1,
#    'more': 1,
#    'than': 3,
#    'confession': 1,
#    'might': 2,
#    'press': 1,
#    'button': 1,
#    'so': 3,
#    'know': 5,
#    'discretion': 1,
#    'caught': 1,
#    'feelings': 1,
#    'feel': 3,
#    'sabotage': 1,
#    'community': 1,
#    'makin': 1,
#    'killin': 2,
#    'killer': 2,
#    'emancipation': 2,
#    'real': 2,
#    'prechorus': 2,
#    'blacker': 9,
#    'berry': 8,
#    'sweeter': 6,
#    'juice': 6,
#    'bigger': 3,
#    'shoot': 2,
#    'chorus': 2,
#    'assassin': 2,
#    'said': 2,
#    'treat': 2,
#    'like': 5,
#    'slave': 3,
#    'cah': 8,
#    'woi': 2,
#    'whole': 2,
#    'heap': 2,
#    'pain': 2,
#    'man': 3,
#    'put': 2,
#    'inna': 2,
#    'chains': 4,
#    'imagine': 2,
#    'now': 4,
#    'gold': 2,
#    'full': 2,
#    'rocks': 2,
#    'how': 6,
#    'no': 3,
#    'whip': 4,
#    'left': 2,
#    'scars': 2,
#    'pon': 4,
#    'back': 2,
#    'have': 2,
#    'parked': 2,
#    'block': 4,
#    'them': 2,
#    'doomed': 2,
#    'start': 4,
#    'remember': 2,
#    'every': 2,
#    'race': 2,
#    'jus': 2,
#    'member': 2,
#    'dat': 2,
#    '2': 1,
#    'evident': 1,
#    'irrelevant': 1,
#    'society': 1,
#    'telling': 1,
#    'penitentiary': 1,
#    'would': 1,
#    'only': 3,
#    'hire': 1,
#    'curse': 1,
#    'till': 1,
#    'dead': 1,
#    'church': 1,
#    'with': 4,
#    'fake': 1,
#    'prophesizing': 1,
#    'ima': 1,
#    'be': 2,
#    'another': 1,
#    'head': 1,
#    'institutionalized': 1,
#    'manipulation': 1,
#    'lies': 1,
#    'reciprocation': 1,
#    'freedom': 1,
#    'live': 2,
#    'much': 2,
#    'yourself': 1,
#    'jealous': 1,
#    'wisdom': 1,
#    'cards': 1,
#    'dealt': 1,
#    'pull': 2,
#    'up': 2,
#    'fill': 1,
#    'tank': 1,
#    'then': 3,
#    'peel': 1,
#    'out': 1,
#    'muscle': 1,
#    'cars': 1,
#    'ups': 1,
#    'show': 1,
#    'these': 2,
#    'wheels': 1,
#    'bout': 1,
#    'ah': 1,
#    'successful': 1,
#    'special': 1,
#    'katzkins': 1,
#    'on': 2,
#    'radar': 1,
#    'bitch': 1,
#    'can': 5,
#    'help': 1,
#    'tell': 5,
#    'making': 1,
#    '3': 1,
#    'when': 4,
#    'if': 1,
#    'listenin': 1,
#    'sure': 1,
#    'agree': 1,
#    'plot': 1,
#    'generational': 1,
#    'hatred': 1,
#    'genocism': 1,
#    'grimy': 1,
#    'little': 1,
#    'justification': 1,
#    'heart': 1,
#    'aryan': 1,
#    'name': 1,
#    'tyrone': 1,
#    'darius': 1,
#    'excuse': 1,
#    'french': 1,
#    'yall': 1,
#    'blunt': 1,
#    'gets': 1,
#    'cause': 3,
#    'threats': 1,
#    'ways': 1,
#    'deceitful': 1,
#    'because': 1,
#    'love': 1,
#    'desert': 1,
#    'eagle': 1,
#    'thinkin': 1,
#    'maliciously': 1,
#    'he': 1,
#    'chain': 1,
#    'gone': 1,
#    'bleed': 1,
#    'him': 1,
#    'funny': 1,
#    'zulu': 1,
#    'xhosa': 1,
#    'go': 1,
#    'war': 1,
#    'two': 1,
#    'tribal': 1,
#    'armies': 1,
#    'build': 1,
#    'destroy': 1,
#    'remind': 1,
#    'compton': 1,
#    'crip': 1,
#    'gangs': 1,
#    'next': 1,
#    'door': 1,
#    'beefin': 1,
#    'pirus': 1,
#    'death': 1,
#    'settle': 1,
#    'score': 1,
#    'matter': 1,
#    'preach': 1,
#    'panthers': 1,
#    'georgia': 1,
#    'state': 1,
#    'marcus': 1,
#    'garvey': 1,
#    'got': 1,
#    'answers': 1,
#    'try': 1,
#    'celebrate': 1,
#    'february': 1,
#    'bday': 1,
#    'eat': 1,
#    'watermelon': 1,
#    'chicken': 1,
#    'koolaid': 1,
#    'weekdays': 1,
#    'jump': 1,
#    'high': 1,
#    'enough': 1,
#    'michael': 1,
#    'jordan': 1,
#    'endorsements': 1,
#    'watch': 1,
#    'bet': 1,
#    'urban': 1,
#    'support': 1,
#    'important': 1,
#    'why': 1,
#    'did': 1,
#    'weep': 1,
#    'trayvon': 1,
#    'martin': 1,
#    'gang': 1,
#    'banging': 1,
#    'make': 1,
#    'kill': 1,
#    'instrumental': 1,
#    'outro': 1}}]

# %% [markdown]
# # Lyrics positive and negative emotion classification
# # Custom Lexicon-Based, Vader, and TextBlob Sentiment Analysis

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, col
from pyspark.sql.types import StringType
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')
from textblob import TextBlob


# Define your stopwords
STOPWORDS = ['', 'a', '*', 'and', 'is', 'of', 'the', '\n\n', '\n', 'by', '[', ']', '(', ')','as','it','my','was','for','gon',
             'that','had','in','or','on','i','your',"i'm",'at','you','to','then','just','it','it,','me','can','we','with',
             'she','her','he','his','up','get','got','-','–','—','--','!','/','our','are','me','with','going',"it's",'by:','9,','still','2015:',
            "don't","(it's","on,",'i’m','these','•','j','s','m','d','?',"i", "the", "you", "in", "a", "and", "it", "that", "to", "of", "is", "me",
            "this", "all", "out", "like", "im", "do", "dont", "be", "was", "they", "how", "are", "for", "have", "not", "with", "at", "on", "if", "my", "up",
            "your", "then", "we", "as", "but", "so", "or", "an", "am", "by", "can","from", "just", "what", "he", "him", "his", "her", "she", "our", "us","their",
            "who", "them", "got", "yeah", "know", "when", "thats", "say","its", "where", "had", "see", "look", "now", "take", "tell", "no","get","1","2","3",
            "there","na","oh","uh","la","beyoncé","john","de","ты","woo","aw","les","и",'one','niggas','cant','aint', 'al','aye','will','ar','huh','anna',
             'joey''eh','rana','ar','eh','eh','aha','yes','noel','i-oh-oh-oh',"we're",'rone','wro','ima','tryna','theres','been','left','okay',
             'did','yo','only','ooh','ive','ya','too','bout','done','.','than','gonna','em','seen','ayy','till','used','bout','might','lil','off',
             'were','should','could','said','ho','hey','youre','outro','yall','ho','hoes']

sentiment_lexicon = {
    'positive': ['good', 'happy', 'joy', 'excellent','love','fun','glow','dans'],
    'negative': ['bad', 'sad', 'hate', 'terrible','shit','fuck','bitch','nigga','devil','beat','shoot','niggas',
                 'fucking','victim','dirty','beat','sick','never','kill']
}

# Create a Spark DataFrame from the RDD
spark = SparkSession.builder.getOrCreate()
df = spark.createDataFrame(rdd_with_word_counts)

# Flatten the 'word_counts' dictionary into separate columns
df = df.select("song", "word_counts")

# Use the explode function to split the 'word_counts' dictionary into separate rows
df = df.select("song", explode("word_counts").alias("word", "count"))

# Filter out stopwords
df = df.filter(~col("word").isin(STOPWORDS))

sia = SentimentIntensityAnalyzer()

@udf(StringType())
def classify_sentiment(word):
    if word in sentiment_lexicon['positive']:
        return 'positive'
    elif word in sentiment_lexicon['negative']:
        return 'negative'
    else:
        return 'neutral'

@udf(StringType())
def classify_sentiment_vader(text):
    sentiment_score = sia.polarity_scores(text)['compound']

    if sentiment_score >= 0.05:
        return 'positive'
    elif sentiment_score <= -0.05:
        return 'negative'
    else:
        return 'neutral'

@udf(StringType())
def classify_sentiment_textblob(text):
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity

    if polarity > 0:
        return 'positive'
    elif polarity < 0:
        return 'negative'
    else:
        return 'neutral'


# Apply VADER sentiment analysis UDF
df = df.withColumn("sentiment_vader", classify_sentiment_vader(col("word")))
df = df.withColumn("sentiment", classify_sentiment(col("word")))
df = df.withColumn("sentiment_textblob", classify_sentiment_textblob(col("word")))

# Group by Song and calculate sentiment counts
song_sentiment_vader = df.groupBy("song", "sentiment_vader").sum("count").groupBy("song").pivot("sentiment_vader", ["positive", "negative", "neutral"]).sum("sum(count)").fillna(0)
song_sentiment = df.groupBy("song", "sentiment").sum("count").groupBy("song").pivot("sentiment", ["positive", "negative", "neutral"]).sum("sum(count)").fillna(0)

song_sentiment_vader = song_sentiment_vader.withColumnRenamed("positive", "positive_count_vader").withColumnRenamed("negative", "negative_count_vader").withColumnRenamed("neutral", "neutral_count_vader")
song_sentiment = song_sentiment.withColumnRenamed("positive", "positive_count").withColumnRenamed("negative", "negative_count").withColumnRenamed("neutral", "neutral_count")

# Calculate final sentiment based on counts
song_sentiment_vader = song_sentiment_vader.withColumn("final_sentiment_vader", when(song_sentiment_vader["positive_count_vader"] > song_sentiment_vader["negative_count_vader"], "positive").otherwise("negative"))
song_sentiment = song_sentiment.withColumn("final_sentiment", when(song_sentiment["positive_count"] > song_sentiment["negative_count"], "positive").otherwise("negative"))

# Join sentiment information back with the original DataFrame
df = df.join(song_sentiment_vader.select("song", "final_sentiment_vader","positive_count_vader","negative_count_vader"), on="song", how="left") \
    .join(song_sentiment.select("song", "final_sentiment","positive_count","negative_count"), on="song", how="left")

# Show the updated DataFrame
df.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# +--------------------+----------+-----+---------------+---------+------------------+---------------------+--------------------+--------------------+---------------+--------------+--------------+
# |                song|      word|count|sentiment_vader|sentiment|sentiment_textblob|final_sentiment_vader|positive_count_vader|negative_count_vader|final_sentiment|positive_count|negative_count|
# +--------------------+----------+-----+---------------+---------+------------------+---------------------+--------------------+--------------------+---------------+--------------+--------------+
# |Kendrick-lamar-sw...|      vibe|    1|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|       bad|    1|       negative| negative|          negative|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|   thought|    2|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|     homie|    1|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|   granted|    1|       positive|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|       fit|    1|       positive|  neutral|          positive|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|   refrain|    3|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|      bang|    8|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|    record|    1|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|babysittin|    3|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|   chicago|    1|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|      grow|    1|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|      pass|    4|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|      pool|   12|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|  opposite|    1|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|capitalize|    1|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|  kendrick|    3|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|     notch|    3|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|    bridge|    1|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# |Kendrick-lamar-sw...|     shots|    8|        neutral|  neutral|           neutral|             negative|                  20|                  21|       negative|             6|            13|
# +--------------------+----------+-----+---------------+---------+------------------+---------------------+--------------------+--------------------+---------------+--------------+--------------+
# only showing top 20 rows

# %% [markdown]
# # Compare Custom Lexicon-Based, Vader, and TextBlob Sentiment Analysis

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the value counts of the "sentiment_vader" column
value_counts_vader = df.select('sentiment_vader').groupBy('sentiment_vader').count()

# Show the value counts
value_counts_vader.show()

# Calculate the value counts of the "sentiment_textblob" column
value_counts_textblob = df.select('sentiment_textblob').groupBy('sentiment_textblob').count()

# Show the value counts
value_counts_textblob.show()

# Calculate the value counts of the "sentiment" column
value_counts_sentiment = df.select('sentiment').groupBy('sentiment').count()

# Show the value counts
value_counts_sentiment.show()

# Create subplots using Seaborn and Matplotlib
sns.set(style="darkgrid")

# Set up the figure with three subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16, 6))

# Plot for sentiment_textblob
sns.countplot(data=df.toPandas(), x="sentiment_textblob", ax=axes[0])
axes[0].set_xlabel("Predicted Song's Sentiment (Text Blob)")
axes[0].set_ylabel("Count")
axes[0].set_title("Song Sentiment Distribution (Text Blob)")

# Plot for sentiment_vader
sns.countplot(data=df.toPandas(), x="sentiment_vader", ax=axes[1])
axes[1].set_xlabel("Predicted Song's Sentiment (VADER)")
axes[1].set_ylabel("Count")
axes[1].set_title("Song Sentiment Distribution (VADER)")

# Plot for sentiment
sns.countplot(data=df.toPandas(), x="sentiment", ax=axes[2])
axes[2].set_xlabel("Predicted Song's Sentiment")
axes[2].set_ylabel("Count")
axes[2].set_title("Song Sentiment Distribution")

# Adjust layout for better spacing
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# +---------------+------+
# |sentiment_vader| count|
# +---------------+------+
# |       positive| 29743|
# |        neutral|320379|
# |       negative| 32497|
# +---------------+------+
#
# +------------------+------+
# |sentiment_textblob| count|
# +------------------+------+
# |          positive| 30010|
# |           neutral|331211|
# |          negative| 21398|
# +------------------+------+
#
# +---------+------+
# |sentiment| count|
# +---------+------+
# | positive|  2509|
# |  neutral|374106|
# | negative|  6004|
# +---------+------+

# %% [markdown]
# # Exploring Sentimental Tones in American Song Lyrics: An Analysis of Positive and Negative Emotion Distribution

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the value counts of the "final_sentiment_vader" column
value_counts = df.select('final_sentiment_vader').groupBy('final_sentiment_vader').count().alias("Predicted Song's Sentiment")

# Show the value counts
value_counts.show()

# Define a custom color palette
custom_palette = ["#007acc","#44935b"]  # You can customize the colors

# Create a countplot using Seaborn with the custom color palette
sns.set(style="darkgrid")
plt.figure(figsize=(8, 6))
sns.countplot(data=df.toPandas(), x="final_sentiment_vader", palette=custom_palette)
plt.xlabel("Predicted Song's Sentiment")
plt.ylabel("Count")
plt.title("Song Sentiment Distribution")
plt.show()
# Out:
# StatementMeta(90404a2c-b491-4c64-937a-8564b8338d6d, 31, 11, Finished, Available)
# +---------------------+-------+
# |final_sentiment_vader|  count|
# +---------------------+-------+
# |             positive|1619888|
# |             negative|4547196|
# +---------------------+-------+

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the value counts of the "final_sentiment_vader" column
value_counts = df.select('sentiment_vader').groupBy('sentiment_vader').count()

# Show the value counts
value_counts.show()

# Create a countplot using Seaborn
sns.set(style="darkgrid")
plt.figure(figsize=(8, 6))
sns.countplot(data=df.toPandas(), x="sentiment_vader")
plt.xlabel("Predicted Song's Sentiment")
plt.ylabel("Count")
plt.title("Song Sentiment Distribution")
plt.show()
# Out:
# StatementMeta(90404a2c-b491-4c64-937a-8564b8338d6d, 22, 12, Finished, Available)
# +---------------+-------+
# |sentiment_vader|  count|
# +---------------+-------+
# |       positive| 357418|
# |        neutral|5331977|
# |       negative| 477689|
# +---------------+-------+

# %% [markdown]
# # Word Cloud Analysis of American Song Lyrics

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from pyspark.sql import functions as F

# Assuming you have a DataFrame with columns 'word', 'count'
word_counts = df.groupBy("word").sum("count").withColumnRenamed("sum(count)", "count").orderBy("count", ascending=False)

# Convert the top words to a Pandas DataFrame
top_words_pd = word_counts.toPandas()

# Generate a word cloud from the word counts
wordcloud = WordCloud(width=800, height=400, background_color ='white').generate_from_frequencies(dict(zip(top_words_pd['word'], top_words_pd['count'])))

# Display the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Most Frequent Words')
plt.show()

# %% [markdown]
# # Exploring Word Frequencies: Top 15 Words in American Song Lyrics

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from pyspark.sql import functions as F

# Assuming you have a DataFrame with columns 'word', 'count'
word_counts = df.groupBy("word").sum("count").withColumnRenamed("sum(count)", "count").orderBy("count", ascending=False)

# Select the top 10 words with the highest counts
top_10_words = word_counts.limit(15).toPandas()

# Set the style and create a figure
sns.set(style="darkgrid")
plt.figure(figsize=(10, 6))

# Use a combination of "Blues" and "Greens" palettes with more shades and a reversed order for darkness
blue_green_palette = sns.color_palette("Blues_d", 5)[::-1]

# Create a bar chart with the custom dark blue-green palette
sns.barplot(data=top_10_words, x="word", y="count", palette=blue_green_palette)

plt.xlabel("Song Word")
plt.ylabel("Frequency")
plt.title("Top 10 Words by Count")
plt.xticks(rotation=45, ha="right")

plt.show()  # Display the bar chart
# Out:
# <ipython-input-18-46beae5b8095>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10_words, x="word", y="count", palette=blue_green_palette)
# <ipython-input-18-46beae5b8095>:19: UserWarning:
# The palette list has fewer values (5) than needed (15) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(data=top_10_words, x="word", y="count", palette=blue_green_palette)

# %% [markdown]
# # Song Data

# %%
from pyspark.sql.functions import col, when, array_contains
from pyspark.sql import SparkSession
from pyspark.sql.functions import month, dayofmonth, when
from pyspark.sql.functions import to_date

spark = SparkSession.builder.appName("ReadJSON").config("spark.sql.legacy.timeParserPolicy", "LEGACY").getOrCreate()
spark = SparkSession.builder.appName("ReadJSON").getOrCreate()

df_songinfo = spark.read.json("/content/song_info.json")

df_songinfo = df_songinfo.withColumn(
    'tags',
    when(
        (array_contains(col('tags'), 'Rap') & array_contains(col('tags'), 'Pop')) |
        (array_contains(col('tags'), 'Rock') & array_contains(col('tags'), 'Heavy Metal')) |
        (array_contains(col('tags'), 'Rock') & array_contains(col('tags'), 'R&B')) |
        (array_contains(col('tags'), 'Jazz') & array_contains(col('tags'), 'R&B')) |
        (array_contains(col('tags'), 'Electronic') & array_contains(col('tags'), 'R&B')) |
        (array_contains(col('tags'), 'K-Pop') & array_contains(col('tags'), 'R&B')), 'Mix'
    )
    .when(array_contains(col('tags'), 'Rap'), 'Rap')
    .when(array_contains(col('tags'), 'Pop'), 'Pop')
    .when(array_contains(col('tags'), 'R&B'), 'R&B')
    .when(array_contains(col('tags'), 'Rock'), 'Rock')
    .when(array_contains(col('tags'), 'Jazz'), 'Jazz')
    .when(array_contains(col('tags'), "K-Pop (케이팝)"), 'K-Pop')
    .when(array_contains(col('tags'), 'Heavy Metal'), 'Heavy Metal')
    .when(array_contains(col('tags'), 'Electronic'), 'Electronic')
    .otherwise('Non-Music')
)

# Extract month and day from the release_date
df_songinfo = df_songinfo.withColumn("release_date", to_date(col("release_date"), "MMMM dd, yyyy"))
df_songinfo = df_songinfo.filter(col("release_date").isNotNull())
df_songinfo = df_songinfo.withColumn("month", month(col("release_date")))

# Create a new column for seasons based on the month and day
df_songinfo = df_songinfo.withColumn(
    "season",
    when((col("month") >= 3) & (col("month") <= 5), "Spring")
    .when((col("month") >= 6) & (col("month") <= 8), "Summer")
    .when((col("month") >= 9) & (col("month") <= 11), "Fall")
    .otherwise("Winter")
)

# Select relevant columns including the new "season" column
df_songinfo = df_songinfo.select("url_name", "title", "primary_artist", "release_date", "views", "tags", "season")

# Show the resulting DataFrame
df_songinfo.show()
# Out:
# +--------------------+--------------------+--------------+------------+--------+----+------+
# |            url_name|               title|primary_artist|release_date|   views|tags|season|
# +--------------------+--------------------+--------------+------------+--------+----+------+
# |Kendrick-lamar-sw...|Swimming Pools (D...|Kendrick-lamar|  2012-07-31| 5589280| Rap|Summer|
# |Kendrick-lamar-mo...|         Money Trees|Kendrick-lamar|  2012-10-22| 4592003| Rap|  Fall|
# |Kendrick-lamar-xx...|                XXX.|Kendrick-lamar|  2017-04-14| 4651514| Mix|Spring|
# |A-ap-rocky-fuckin...|    Fuckin’ Problems|    A-ap-rocky|  2012-10-24| 7378309| Rap|  Fall|
# |Kendrick-lamar-dn...|                DNA.|Kendrick-lamar|  2017-04-14| 5113687| Rap|Spring|
# |Kendrick-lamar-po...|      Poetic Justice|Kendrick-lamar|  2012-10-22| 4137688| Rap|  Fall|
# |Kendrick-lamar-bi...|Bitch, Don’t Kill...|Kendrick-lamar|  2012-10-22| 4455762| Rap|  Fall|
# |Kendrick-lamar-ki...|          King Kunta|Kendrick-lamar|  2015-03-15| 3976102| Rap|Spring|
# |Big-sean-control-...|             Control|      Big-sean|  2013-08-12| 4389308| Rap|Summer|
# |Kendrick-lamar-ma...|        m.A.A.d city|Kendrick-lamar|  2012-10-22| 6120127| Rap|  Fall|
# |Kendrick-lamar-hu...|             HUMBLE.|Kendrick-lamar|  2017-03-30|10210428| Rap|Spring|
# |Schoolboy-q-colla...|      Collard Greens|   Schoolboy-q|  2013-06-11| 2530650| Rap|Summer|
# |Kendrick-lamar-el...|            ELEMENT.|Kendrick-lamar|  2017-04-14| 2506800| Mix|Spring|
# |Kendrick-lamar-th...|The Blacker the B...|Kendrick-lamar|  2015-02-09| 2557473| Rap|Winter|
# |Kendrick-lamar-lo...|            LOYALTY.|Kendrick-lamar|  2017-04-14| 2524552| Mix|Spring|
# |Kendrick-lamar-al...|             Alright|Kendrick-lamar|  2015-03-15| 2886454| Rap|Spring|
# |Kendrick-lamar-ba...|  Backseat Freestyle|Kendrick-lamar|  2012-10-15| 3447535| Rap|  Fall|
# |Kendrick-lamar-lo...|               LOVE.|Kendrick-lamar|  2017-04-14| 3533126| Mix|Spring|
# |Travis-scott-goos...|          goosebumps|  Travis-scott|  2016-09-02| 3881901| Rap|  Fall|
# |Kendrick-lamar-si...|Sing About Me, I’...|Kendrick-lamar|  2012-10-22| 2329481| Mix|  Fall|
# +--------------------+--------------------+--------------+------------+--------+----+------+
# only showing top 20 rows

# %% [markdown]
# # Combining song data and lyric data

# %%
from pyspark.sql.functions import col

# Join df_resultt and df_songinfo and select the desired columns
filtered_df = df.join(df_songinfo, df['song'] == df_songinfo['url_name'], 'inner').select(df_songinfo['primary_artist'],df['song'],df['final_sentiment_vader'],df['positive_count_vader'],df['negative_count_vader'],df_songinfo['release_date'],df['word'],df['count'],df_songinfo['views'],df_songinfo['tags'],df_songinfo['season'])


filtered_df = filtered_df.orderBy(col('count').desc())
filtered_df.show()
# Out:
# +--------------------+--------------------+---------------------+--------------------+--------------------+------------+-------+-----+------+----+------+
# |      primary_artist|                song|final_sentiment_vader|positive_count_vader|negative_count_vader|release_date|   word|count| views|tags|season|
# +--------------------+--------------------+---------------------+--------------------+--------------------+------------+-------+-----+------+----+------+
# |           Daft-punk|Daft-punk-lose-yo...|             negative|                  14|                  46|  2013-08-13|   come|  320|337798| Pop|Summer|
# |               Buddy|  Buddy-black-lyrics|             negative|                   3|                  26|  2018-07-20|  black|  232| 55931| Rap|Summer|
# |            Skrillex|Skrillex-summit-l...|             positive|                   4|                   0|  2013-01-02|breathe|  204| 22925|Rock|Winter|
# |            Lil-pump|Lil-pump-gucci-ga...|             negative|                  22|                  56|  2018-03-17|  gucci|  200|124214| Rap|Spring|
# |                Kyle|     Kyle-fun-lyrics|             positive|                 216|                  20|  2013-08-05|    fun|  190| 50670| Rap|Summer|
# |The-breakfast-clu...|The-breakfast-clu...|             positive|                 373|                 249|  2013-07-01|    jay|  188|  9703| Rap|Summer|
# |     Kyle-and-mr-man|Kyle-and-mr-man-b...|             negative|                   9|                  20|  2013-06-04|   bang|  188| 39103| Rap|Summer|
# |            Lil-pump|Lil-pump-gucci-ga...|             negative|                  22|                  56|  2018-03-17|   gang|  186|124214| Rap|Spring|
# |         Lupe-fiasco|Lupe-fiasco-high-...|             positive|                  16|                  12|  2017-02-10|   high|  180| 10294| Rap|Winter|
# |   Chance-the-rapper|Chance-the-rapper...|             negative|                  10|                  17|  2018-07-18|   wala|  177|110970| Rap|Summer|
# |      Run-the-jewels|Run-the-jewels-ru...|             negative|                  25|                  25|  2015-09-23|     dy|  176| 15779| Rap|  Fall|
# |         Jon-bellion|Jon-bellion-all-t...|             negative|                   6|                 193|  2015-04-14|    low|  175|793104| Pop|Spring|
# |             Rihanna|Rihanna-goodnight...|             negative|                   0|                   0|  2016-01-28|  night|  172|121689| Pop|Winter|
# |             50-cent|50-cent-nigga-nig...|             negative|                  18|                  26|  2015-12-09|  nigga|  168| 29955| Rap|Winter|
# |          Charli-xcx|Charli-xcx-shake-...|             negative|                  10|                 188|  2019-09-13|  shake|  164| 39159| Mix|  Fall|
# |               Migos|Migos-versace-lyrics|             positive|                   9|                   5|  2013-07-09|versace|  163|179819| Rap|Summer|
# |          Kanye-west|Kanye-west-lord-l...|             positive|                  42|                  34|  2010-09-17|   lord|  161| 75948| Rap|  Fall|
# |               Lil-b| Lil-b-i-cook-lyrics|             negative|                   6|                  17|  2010-10-05|   swag|  160| 17739| Rap|  Fall|
# |   Justin-timberlake|Justin-timberlake...|             negative|                  24|                  27|  2018-02-02|   glow|  160| 34797| Pop|Winter|
# |              G-eazy|G-eazy-lotta-that...|             negative|                   9|                  41|  2014-06-10|  lotta|  159|232559| Rap|Summer|
# +--------------------+--------------------+---------------------+--------------------+--------------------+------------+-------+-----+------+----+------+
# only showing top 20 rows

# %% [markdown]
# # Artist Data

# %%
rd_artistinfo = spark.read.json("/content/artist_info.json")
rd_artistinfo.show()
# Out:
# +---------+-----+--------------------+--------------------+------------------+
# |followers|   iq|               roles|               songs|          url_name|
# +---------+-----+--------------------+--------------------+------------------+
# |       15|    0|                  []|[Post-malone-rock...|        Mike-bozzi|
# |     4902|  175|   [Verified Artist]|[Beyonce-drunk-in...|             Jay-z|
# |     9313|25492|[Verified Artist,...|[A-ap-rocky-fucki...|        A-ap-rocky|
# |       46|    0|                  []|[Nf-let-you-down-...|    Tommee-profitt|
# |        3|    0|                  []|[Sam-smith-too-go...|   Capitol-records|
# |        7|    0|                  []|[Drake-hotline-bl...|      Chris-athens|
# |       24|    0|                  []|[Andy-mineo-uncom...|  Joseph-prielozny|
# |      247|    0|                  []|[Drake-nice-for-w...|  Ol-dirty-bastard|
# |     5431| 3873|[Verified Artist,...|[Drake-in-my-feel...|         Lil-wayne|
# |     1092| 2118|[Verified Artist,...|[Pusha-t-nosetalg...|           Krs-one|
# |    13203|    0|                  []|[Drake-gods-plan-...|             Drake|
# |       44|    0|                  []|[Knaan-immigrants...|             Knaan|
# |      264|  269|   [Verified Artist]|[Rich-gang-lifest...|London-on-da-track|
# |     8376|36080|[Verified Artist,...|[Rick-ross-stay-s...|               Nas|
# |     1803|    0|                  []|[Childish-gambino...|        Young-thug|
# |     2340| 6113|[Verified Artist,...|[A-ap-rocky-1trai...|          Big-krit|
# |     2566| 1154|[Verified Artist,...|[The-game-100-lyr...|          The-game|
# |      476|    0|                  []|[Travis-scott-sic...|         Mike-dean|
# |     4429|52476|[Verified Artist,...|[Kanye-west-mercy...|           Pusha-t|
# |     1594| 3996|[Verified Artist,...|[Nf-let-you-down-...|                Nf|
# +---------+-----+--------------------+--------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# # Combining Merge data and artist data

# %%
filtered_df = filtered_df.join(rd_artistinfo, filtered_df['primary_artist'] == rd_artistinfo['url_name'], 'inner').select(filtered_df['primary_artist'],filtered_df['song'],filtered_df['final_sentiment_vader'],filtered_df['release_date'],filtered_df['tags'],filtered_df['season'],filtered_df['views'],rd_artistinfo['followers'])

filtered_df = filtered_df.dropDuplicates()

filtered_df = filtered_df.orderBy(col('count').desc())
filtered_df.show()
# Out:
# +-----------------+--------------------+---------------------+------------+----+------+------+---------+
# |   primary_artist|                song|final_sentiment_vader|release_date|tags|season| views|followers|
# +-----------------+--------------------+---------------------+------------+----+------+------+---------+
# |          Rihanna|Rihanna-goodnight...|             negative|  2016-01-28| Pop|Winter|121689|     4551|
# |        Daft-punk|Daft-punk-around-...|             negative|  1997-01-20| Pop|Winter| 56205|      606|
# |               Yc|     Yc-racks-lyrics|             positive|  2011-04-05| Rap|Spring| 84945|        2|
# |        Daft-punk|Daft-punk-superhe...|             negative|  2001-02-26|Rock|Winter| 12487|      606|
# |          Beyonce|Beyonce-creole-ly...|             negative|  2006-09-04| Pop|  Fall|  9591|     3081|
# |           Halsey|Halsey-dont-play-...|             positive|  2017-06-02| Pop|Summer|191750|     1784|
# |         2-chainz|2-chainz-its-a-vi...|             negative|  2017-03-09| Rap|Spring|390663|     4120|
# |   Cardi-b-and-yg|Cardi-b-and-yg-sh...|             negative|  2018-04-04| Rap|Spring|424509|        1|
# |            Migos|Migos-bbo-bad-bit...|             negative|  2018-01-26| Rap|Winter|294722|     3107|
# |The-notorious-big|The-notorious-big...|             negative|  1994-09-13| Rap|  Fall|618558|     1700|
# |      Death-grips|Death-grips-big-d...|             negative|  2014-06-08| Rap|Summer| 44012|      778|
# |  Michael-jackson|Michael-jackson-e...|             negative|  1995-06-16| Pop|Summer|166638|      935|
# |    Playaz-circle|Playaz-circle-stu...|             negative|  2009-04-21| Rap|Spring|  5128|        2|
# |         Lil-pump|Lil-pump-aight-ly...|             negative|  2017-10-01| Rap|  Fall|  5133|     1595|
# |       Snoop-dogg|Snoop-dogg-swivel...|             positive|  2017-05-15| Rap|Spring|  6840|     4102|
# |       Lil-yachty|Lil-yachty-mamaci...|             positive|  2017-04-14| Rap|Spring| 21308|     1365|
# |         Phresher|Phresher-danny-de...|             negative|  2014-09-13| Rap|  Fall|  8943|       17|
# |           Grimes|Grimes-infinite-w...|             positive|  2012-01-31| Pop|Winter| 11764|      591|
# |       Young-thug|Young-thug-big-ra...|             negative|  2015-10-31| Rap|  Fall|140453|     1803|
# |           Jack-u|Jack-u-take-u-the...|             positive|  2014-09-15| Pop|  Fall| 87093|       64|
# +-----------------+--------------------+---------------------+------------+----+------+------+---------+
# only showing top 20 rows

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the value counts of the "final_sentiment_vader" column
value_counts = filtered_df.select( 'final_sentiment_vader').groupBy( 'final_sentiment_vader').count()

# Show the value counts
value_counts.show()

pd_value_counts = value_counts.toPandas()

custom_palette = ["#44935b","#007acc"]  # You can customize the colors

# Set the style of seaborn for better aesthetics (optional)
sns.set(style="whitegrid")

# Create a bar plot using Seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x='final_sentiment_vader', y='count', data=pd_value_counts, palette=custom_palette)

# Set plot labels and title
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Distribution')

# Show the plot
plt.show()
# Out:
# StatementMeta(90404a2c-b491-4c64-937a-8564b8338d6d, 31, 39, Finished, Available)
# +---------------------+-----+
# |final_sentiment_vader|count|
# +---------------------+-----+
# |             positive|10361|
# |             negative|23273|
# +---------------------+-----+

# %% [markdown]
# # Genre Distribution in the American Music Market

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
from pyspark.sql.functions import col

# Calculate the value counts of the "tags" column
value_counts = filtered_df.groupBy('tags').count()

# Convert count column to integer
value_counts = value_counts.withColumn("count", col("count").cast("int"))

# Convert the PySpark DataFrame to a Pandas DataFrame
pandas_df = value_counts.toPandas()

# Sort the DataFrame by count in descending order for better visualization
pandas_df = pandas_df.sort_values(by='count', ascending=False)

blue_color = sns.color_palette("Blues_d", 1)[0]
green_color = sns.color_palette("Greens_d", 1)[0]
red_color = sns.color_palette("Reds_d", 1)[0]
orange_color = sns.color_palette("Oranges_d", 1)[0]

# Combine the shades to create a custom palette
custom_palette = [blue_color, green_color, red_color, orange_color]


# Create a countplot using Seaborn with a logarithmic scale
sns.set(style="darkgrid")
plt.figure(figsize=(15, 6))
sns.barplot(data=pandas_df, x="tags", y="count", palette=custom_palette)

plt.xlabel("Tags")
plt.ylabel("Count (log scale)")
plt.yscale("log")  # Logarithmic scale on the y-axis
plt.title("Tags Distribution")
plt.show()
# Out:
# StatementMeta(90404a2c-b491-4c64-937a-8564b8338d6d, 30, 39, Finished, Available)

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the value counts of the "final_sentiment_vader" column grouped by 'tags'
value_counts = filtered_df.select('final_sentiment_vader', 'tags').groupBy('final_sentiment_vader','tags').count()

# Convert the DataFrame to a Pandas DataFrame for easy plotting
value_counts_pandas = value_counts.toPandas()
custom_palette = ["#44935b","#007acc"]  # You can customize the colors

# Plot the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='tags', y='count', hue='final_sentiment_vader', data=value_counts_pandas,palette=custom_palette)
plt.title('Sentiment Analysis by Tags')
plt.xlabel('Tags')
plt.ylabel('Count')
plt.show()

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
from pyspark.sql.functions import col

# Assuming 'filtered_df' is your PySpark DataFrame

# Calculate the sum of counts for each tag
sum_counts = filtered_df.groupBy('tags').agg({"views": "sum"})

# Convert the PySpark DataFrame to a Pandas DataFrame
pandas_df = sum_counts.toPandas()

# Sort the DataFrame by sum of counts in descending order for better visualization
pandas_df = pandas_df.sort_values(by='sum(views)', ascending=False)

# Define custom colors for the pie chart
blue_color = sns.color_palette("Blues_d", 1)[0]
green_color = sns.color_palette("Greens_d", 1)[0]
red_color = sns.color_palette("Reds_d", 1)[0]
orange_color = sns.color_palette("Oranges_d", 1)[0]
yellow_color = sns.color_palette("YlOrBr", 1)[0]  # or "YlGnBu"

# Combine the shades to create a custom palette
custom_palette = [blue_color, green_color, red_color, orange_color, yellow_color]

# Set a different starting angle
startangle = 400

# Create a pie chart using matplotlib with a smaller size
plt.figure(figsize=(8, 10))
plt.pie(
    pandas_df['sum(views)'],
    labels=pandas_df['tags'],
    colors=custom_palette,
    startangle=startangle  # Adjust the starting angle
)

# Add a title to the plot
plt.title("Tags Distribution (Proportion)")

# Display the pie chart
plt.show()
# Out:
# StatementMeta(90404a2c-b491-4c64-937a-8564b8338d6d, 30, 50, Finished, Available)

# %% [markdown]
# # Seasonal Presence of Songs in the Market

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
from pyspark.sql.functions import col

# Calculate the value counts of the "tags" column
value_counts = filtered_df.groupBy('season').count()

# Convert count column to integer
value_counts = value_counts.withColumn("count", col("count").cast("int"))

# Convert the PySpark DataFrame to a Pandas DataFrame
pandas_df = value_counts.toPandas()

# Sort the DataFrame by count in descending order for better visualization
pandas_df = pandas_df.sort_values(by='count', ascending=False)


green_color = sns.color_palette("Greens_d", 1)[0]
red_color = sns.color_palette("Reds_d", 1)[0]
orange_color = sns.color_palette("Oranges_d", 1)[0]
blue_color = sns.color_palette("Blues_d", 1)[0]

# Combine the shades to create a custom palette
custom_palette = [red_color,green_color,orange_color , blue_color]

# Create a countplot using Seaborn with a logarithmic scale
sns.set(style="darkgrid")
plt.figure(figsize=(15, 6))
sns.barplot(data=pandas_df, x="season", y="count", palette=custom_palette)

plt.xlabel("Season")
plt.ylabel("Number of Songs")
plt.title("Seasonal Distribution")
plt.show()
# Out:
# <ipython-input-18-50f0a1ed8853>:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=pandas_df, x="season", y="count", palette=custom_palette)

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the value counts of the "final_sentiment_vader" column grouped by 'season'
value_counts_season = filtered_df.select('final_sentiment_vader', 'season').groupBy('final_sentiment_vader', 'season').count()

# Convert the DataFrame to a Pandas DataFrame for easy plotting
value_counts_season_pandas = value_counts_season.toPandas()
custom_palette = ["#44935b","#007acc"]  # You can customize the colors

# Plot the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='season', y='count', hue='final_sentiment_vader', data=value_counts_season_pandas,palette=custom_palette)
plt.title('Sentiment Analysis by Season')
plt.xlabel('Season')
plt.ylabel('Count')
plt.show()
# Out:
# StatementMeta(90404a2c-b491-4c64-937a-8564b8338d6d, 33, 27, Finished, Available)

# %% [markdown]
# # Emotional Trends in the Top 15 Most Viewed American Songs: A Focus on Positive and Negative Expressions

# %%
from pyspark.sql import functions as F

# Ensure uniqueness of songs and select the top 10 by views
top_songs_df = (
    filtered_df
    .select('song', 'final_sentiment_vader', 'views')
    .groupBy('song', 'final_sentiment_vader')
    .agg(F.max('views').alias('max_views'))
    .distinct()
    .orderBy('max_views', ascending=False)
    .limit(15)
)

# Convert Spark DataFrame to Pandas DataFrame for plotting
pandas_df = top_songs_df.toPandas()

# Map sentiment to colors
colors = {'positive':'#44935b' , 'negative': '#007acc'}

# Plotting
plt.figure(figsize=(10, 6))
bars = plt.bar(pandas_df['song'], pandas_df['max_views'], color=pandas_df['final_sentiment_vader'].map(colors))

# Adding legend for colors
legend_labels = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[sentiment], markersize=10, label=sentiment.capitalize()) for sentiment in colors.keys()]
plt.legend(handles=legend_labels, title='Sentiment')

plt.title('Top 15 Unique Songs by Views and Sentiment')
plt.xlabel('Song')
plt.ylabel('Views')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# StatementMeta(90404a2c-b491-4c64-937a-8564b8338d6d, 30, 44, Finished, Available)

# %% [markdown]
# # A Exploring the Evolution of Emotional Content in American Song Lyrics: A Time-Series Analysis

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
from pyspark.sql.functions import year

# Calculate the value counts of the "final_sentiment_vader" column grouped by 'tags'
value_counts = (filtered_df.select(year('release_date').alias('release_year'), 'final_sentiment_vader')
                .groupBy('final_sentiment_vader', 'release_year')
                .count())

# Show the value counts
value_counts.show()
# Out:
# +---------------------+------------+-----+
# |final_sentiment_vader|release_year|count|
# +---------------------+------------+-----+
# |             positive|        1964|   10|
# |             positive|        1989|   19|
# |             positive|        1963|   12|
# |             negative|        2006|  336|
# |             negative|        2001|  221|
# |             negative|        1969|   13|
# |             negative|        2011| 1182|
# |             negative|        1987|   21|
# |             positive|        1962|    2|
# |             positive|        1974|   10|
# |             positive|        2005|  135|
# |             negative|        1980|    9|
# |             positive|        1978|    7|
# |             negative|        1971|   10|
# |             negative|        1984|   10|
# |             positive|        1966|   10|
# |             positive|        1993|   29|
# |             negative|        2008|  355|
# |             positive|        1970|    9|
# |             negative|        1965|    9|
# +---------------------+------------+-----+
# only showing top 20 rows

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
from pyspark.sql.functions import year

# Calculate the value counts of the "final_sentiment_vader" column grouped by 'tags'
value_counts = (filtered_df
                .select(year('release_date').alias('release_year'), 'final_sentiment_vader')
                .groupBy('final_sentiment_vader', 'release_year')
                .count())

# Plot the time series
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
sns.lineplot(x="release_year", y="count", hue="final_sentiment_vader", data=value_counts.toPandas())
plt.title("Sentiment Time Series")
plt.xlabel("Release Year")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
from pyspark.sql import Window
from pyspark.sql.functions import sum, col

# Calculate the total count for each release year
total_counts = value_counts.groupBy('release_year').agg(sum('count').alias('total_count'))

# Join the value_counts DataFrame with the total_counts DataFrame
value_counts_with_percentage = (value_counts
                                .join(total_counts, on='release_year', how='inner')
                                .withColumn('percentage', col('count') / col('total_count') * 100))

palette = {'positive': '#44935b', 'negative': '#007acc'}

# Plot the time series
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
sns.lineplot(x="release_year", y="percentage", hue="final_sentiment_vader", data=value_counts_with_percentage.toPandas(),palette=palette)
plt.title("Percentage Distribution of the Songs by Years Sentiment Time Series")
plt.xlabel("Release Year")
plt.ylabel("Percentage")
plt.xticks(rotation=45)
plt.show()
